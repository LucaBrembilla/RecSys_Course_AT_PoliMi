# %%
# !pip install "numpy<1.24.0"
# Out:
# Requirement already satisfied: numpy<1.24.0 in d:\anaconda\lib\site-packages (1.23.5)

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.23.5

# %%
import time
import pandas as pd
import numpy as np
import scipy.sparse as sps
import random as rnd

from scipy.sparse import *

# %%
urm_path = './content/data_train.csv'
urm_all_df = pd.read_csv(filepath_or_buffer=urm_path,
                                sep=",",
                                header=0,
                                dtype={0:int, 1:int, 2:float},
                                engine='python')

urm_all_df.columns = ["UserID", "ItemID", "Interaction"]
print ("The number of interactions is {}".format(len(urm_all_df)))
# Out:
# The number of interactions is 478730

# %%
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from Data_manager.Movielens.Movielens10MReader import Movielens10MReader

URM_all = sps.coo_matrix((urm_all_df["Interaction"].values,
                          (urm_all_df["UserID"].values, urm_all_df["ItemID"].values)))

URM_train, URM_test = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.8)
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_train, train_percentage = 0.8)
# Out:
# Warning: 616 (4.73 %) of 13025 users have no train items
# Warning: 2560 (19.65 %) of 13025 users have no sampled items
# Warning: 836 (6.42 %) of 13025 users have no train items
# Warning: 3000 (23.03 %) of 13025 users have no sampled items

# %%
from Evaluation.Evaluator import EvaluatorHoldout

cutoff_list=[5, 10, 15]

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=cutoff_list)
evaluator_test = EvaluatorHoldout(URM_test, cutoff_list=cutoff_list)
# Out:
# EvaluatorHoldout: Ignoring 3000 (23.0%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 2560 (19.7%) Users that have less than 1 test interactions

# %% [markdown]
# # Hybrid of models with the same structure
#
# The underlying idea is that if you have some models with the same underlying structure, you can merge them in a single one. The result is to define a function that give the various model's parameters creates a new model with its own parameters.
# In this example we will see how to combine different item-item similarity models in a new one.
#
# In particular: `ItemKNNCFRecommender` and `P3AlphaRecommender`. Both use and learn a similarity matrix to provide recommendations. Notice that here we are merging a KNN-based with a Graph-based model.

# %% [markdown]
# Let's start using our best model yet

# %% [markdown]
# SLIM elasticnet with removed empty profiles and the hyperparameters:
# alpha = 0.0015746723778813712, l1_ratio = 0.005,topK = 100, max_iter=100, tol=1e-4,positive_only=True. On validation it had MAP@10 on val is 0.08221

# %%
from Recommenders.Recommender_utils import check_matrix
from sklearn.linear_model import ElasticNet
from Recommenders.BaseSimilarityMatrixRecommender import BaseItemSimilarityMatrixRecommender
from Recommenders.Similarity.Compute_Similarity_Python import Incremental_Similarity_Builder
from Utils.seconds_to_biggest_unit import seconds_to_biggest_unit
from tqdm import tqdm
from sklearn.exceptions import ConvergenceWarning
import sys
import time


class SLIMElasticNetRecommender(BaseItemSimilarityMatrixRecommender):
    """
    Train a Sparse Linear Methods (SLIM) item similarity model.
    NOTE: ElasticNet solver is parallel, a single intance of SLIM_ElasticNet will
          make use of half the cores available

    See:
        Efficient Top-N Recommendation by Linear Regression,
        M. Levy and K. Jack, LSRS workshop at RecSys 2013.

        SLIM: Sparse linear methods for top-n recommender systems,
        X. Ning and G. Karypis, ICDM 2011.
        http://glaros.dtc.umn.edu/gkhome/fetch/papers/SLIM2011icdm.pdf
    """

    RECOMMENDER_NAME = "SLIMElasticNetRecommender"

    def __init__(self, URM_train, verbose = True):
        super(SLIMElasticNetRecommender, self).__init__(URM_train, verbose = verbose)

    def fit(self, l1_ratio=0.1, alpha = 1.0, positive_only=True, topK = 100):

        assert l1_ratio>= 0 and l1_ratio<=1, "{}: l1_ratio must be between 0 and 1, provided value was {}".format(self.RECOMMENDER_NAME, l1_ratio)
        self.l1_ratio = l1_ratio
        self.positive_only = positive_only
        self.topK = topK


        # initialize the ElasticNet model
        self.model = ElasticNet(alpha=alpha,
                                l1_ratio=self.l1_ratio,
                                positive=self.positive_only,
                                fit_intercept=False,
                                copy_X=False,
                                precompute=True,
                                selection='random',
                                max_iter=100,
                                tol=1e-4)

        URM_train = check_matrix(self.URM_train, 'csc', dtype=np.float32)

        n_items = URM_train.shape[1]

        similarity_builder = Incremental_Similarity_Builder(self.n_items, initial_data_block=self.n_items*self.topK, dtype = np.float32)

        start_time = time.time()
        start_time_printBatch = start_time

        # fit each item's factors sequentially (not in parallel)
        for currentItem in range(n_items):

            # get the target column
            y = URM_train[:, currentItem].toarray()

            # set the j-th column of X to zero
            start_pos = URM_train.indptr[currentItem]
            end_pos = URM_train.indptr[currentItem + 1]

            current_item_data_backup = URM_train.data[start_pos: end_pos].copy()
            URM_train.data[start_pos: end_pos] = 0.0

            # fit one ElasticNet model per column
            self.model.fit(URM_train, y)

            # self.model.coef_ contains the coefficient of the ElasticNet model
            # let's keep only the non-zero values
            nonzero_model_coef_index = self.model.sparse_coef_.indices
            nonzero_model_coef_value = self.model.sparse_coef_.data

            # Check if there are more data points than topK, if so, extract the set of K best values
            if len(nonzero_model_coef_value) > self.topK:
                # Partition the data because this operation does not require to fully sort the data
                relevant_items_partition = np.argpartition(-np.abs(nonzero_model_coef_value), self.topK-1, axis=0)[0:self.topK]
                nonzero_model_coef_index = nonzero_model_coef_index[relevant_items_partition]
                nonzero_model_coef_value = nonzero_model_coef_value[relevant_items_partition]

            similarity_builder.add_data_lists(row_list_to_add=nonzero_model_coef_index,
                                              col_list_to_add=np.ones(len(nonzero_model_coef_index), dtype = int) * currentItem,
                                              data_list_to_add=nonzero_model_coef_value)


            # finally, replace the original values of the j-th column
            URM_train.data[start_pos:end_pos] = current_item_data_backup

            elapsed_time = time.time() - start_time
            new_time_value, new_time_unit = seconds_to_biggest_unit(elapsed_time)


            if time.time() - start_time_printBatch > 300 or currentItem == n_items-1:
                self._print("Processed {} ({:4.1f}%) in {:.2f} {}. Items per second: {:.2f}".format(
                    currentItem+1,
                    100.0* float(currentItem+1)/n_items,
                    new_time_value,
                    new_time_unit,
                    float(currentItem)/elapsed_time))

                sys.stdout.flush()
                sys.stderr.flush()

                start_time_printBatch = time.time()

        self.W_sparse = similarity_builder.get_SparseMatrix()

# %%
slim_elastic_recommender = SLIMElasticNetRecommender(URM_train)
slim_elastic_recommender.fit(alpha = 0.0015746723778813712, l1_ratio = 0.005,topK = 100)

# %%
slim_elastic_recommender.W_sparse
# Out:
# <22348x22348 sparse matrix of type '<class 'numpy.float32'>'
# 	with 2085811 stored elements in Compressed Sparse Row format>

# %%
from scipy.sparse import save_npz
save_npz("./content/item_item_similarity/slim_elastic.npz", slim_elastic_recommender.W_sparse)

# %% [markdown]
# ---

# %% [markdown]
# # IBCF

# %% [markdown]
# Item-base CF where hyperparamters were obtained with 10-fold CV.
# topK = 13,shrink=10, silimarity = 'cosine'

# %%
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender

# %%
IBCFrecommender = ItemKNNCFRecommender(URM_train)
IBCFrecommender.fit(topK=14,shrink=7)
# Out:
# ItemKNNCFRecommender: URM Detected 836 ( 6.4%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 476 ( 2.1%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 1187.38 column/sec. Elapsed time 18.82 sec

# %%
save_npz("./content/item_item_similarity/IBCF.npz", IBCFrecommender.W_sparse)

# %% [markdown]
# ---

# %% [markdown]
# # Evaluation

# %%
def precision(recommended_items, relevant_items):

    is_relevant = np.in1d(recommended_items, relevant_items, assume_unique=True)

    precision_score = np.sum(is_relevant, dtype=np.float32) / len(is_relevant)

    return precision_score

def recall(recommended_items, relevant_items):

    is_relevant = np.in1d(recommended_items, relevant_items, assume_unique=True)

    recall_score = np.sum(is_relevant, dtype=np.float32) / relevant_items.shape[0]

    return recall_score

def AP(recommended_items, relevant_items):

    is_relevant = np.in1d(recommended_items, relevant_items, assume_unique=True)

    # Cumulative sum: precision at 1, at 2, at 3 ...
    p_at_k = is_relevant * np.cumsum(is_relevant, dtype=np.float32) / (1 + np.arange(is_relevant.shape[0]))

    ap_score = np.sum(p_at_k) / np.min([relevant_items.shape[0], is_relevant.shape[0]])

    return ap_score

def evaluate_SLIMelasticnet(URM_test, recommender_object, at=10):

    cumulative_precision = 0.0
    cumulative_recall = 0.0
    cumulative_AP = 0.0

    num_eval = 0


    for user_id in range(URM_test.shape[0]):

        relevant_items = URM_test.indices[URM_test.indptr[user_id]:URM_test.indptr[user_id+1]]

        if len(relevant_items)>0:

            recommended_items = recommender_object.recommend(user_id, cutoff=at,remove_seen_flag=True)
            num_eval+=1

            cumulative_precision += precision(recommended_items, relevant_items)
            cumulative_recall += recall(recommended_items, relevant_items)
            cumulative_AP += AP(recommended_items, relevant_items)

    mean_precision = cumulative_precision / num_eval
    mean_recall = cumulative_recall / num_eval
    MAP = cumulative_AP / num_eval

    print("Recommender results are: Precision = {:.4f}, Recall = {:.4f}, MAP = {:.4f}".format(
        cumulative_precision, cumulative_recall, MAP))
    return MAP, mean_precision, mean_recall

# %%
evaluate_SLIMelasticnet(URM_test,slim_elastic_recommender)
# Out:
# Recommender results are: Precision = 806.0000, Recall = 1132.6422, MAP = 0.0653
# (0.06532939073507661, 0.0770186335403768, 0.10823145921793417)

# %%
evaluate_SLIMelasticnet(URM_test,IBCFrecommender)
# Out:
# Recommender results are: Precision = 759.5000, Recall = 1128.5813, MAP = 0.0607
# (0.06070750121552377, 0.07257525083612454, 0.1078434143433888)

# %% [markdown]
# ---

# %% [markdown]
# Now that we have both models fit with `URM_train` how can we merge them?

# %% [markdown]
# Well, we could take the advantage that they have the same underlying structure, i.e. a similarity matrix

# %%
slim_elastic_recommender.W_sparse
# Out:
# <22348x22348 sparse matrix of type '<class 'numpy.float32'>'
# 	with 2085811 stored elements in Compressed Sparse Row format>

# %%
IBCFrecommender.W_sparse
# Out:
# <22348x22348 sparse matrix of type '<class 'numpy.float32'>'
# 	with 305280 stored elements in Compressed Sparse Row format>

# %% [markdown]
# When we create hybrids we always have to account for:
# * A weight, which is a hyperparameter to tune.
# * What is the range and distribution of the values we are merging
#
# Imagine that the values of one similarity are orders of magnitude higher than the other, then the smaller values would get absorbed by the bigger ones.

# %%
alpha = 0.2
new_similarity = (1 - alpha) * slim_elastic_recommender.W_sparse + alpha * IBCFrecommender.W_sparse
new_similarity
# Out:
# <22348x22348 sparse matrix of type '<class 'numpy.float32'>'
# 	with 2115592 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Moreover, we can apply the same optimizations to this similarity as we applied to the others (for example: topK neighbors)
#
# The framework includes a recommender class which supports a custom similarity

# %%
from Recommenders.KNN.ItemKNNCustomSimilarityRecommender import ItemKNNCustomSimilarityRecommender

recommender_object = ItemKNNCustomSimilarityRecommender(URM_train)
recommender_object.fit(new_similarity)
# Out:
# ItemKNNCustomSimilarityRecommender: URM Detected 836 ( 6.4%) users with no interactions.
# ItemKNNCustomSimilarityRecommender: URM Detected 476 ( 2.1%) items with no interactions.

# %%
evaluate_SLIMelasticnet(URM_test,recommender_object)
# Out:
# Recommender results are: Precision = 833.3000, Recall = 1220.9303, MAP = 0.0677
# (0.06770425768651123, 0.07962732919255107, 0.11666796467752119)

# %% [markdown]
# # Hybrid of models with different structure
#
# We just saw the case where models had compatible structure (ItemKNN with P3Alpha) but there are certain cases where we want to combine recommenders with different underlying structures. For instance ItemKNN and UserKNN or ItemKNN with PureSVD.
#
# In this case we cannot combine the model parameters themselves, rather we can combine the *predictions*.

# %%
from Recommenders.MatrixFactorization.PureSVDRecommender import PureSVDRecommender

pureSVD = PureSVDRecommender(URM_train)
pureSVD.fit()
# Out:
# PureSVDRecommender: URM Detected 56 ( 0.5%) items with no interactions.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... done in 5.26 sec

# %% [markdown]
# We can combine the predictions via a weighted average

# %%
user_id = 50

item_scores_itemknn = itemKNNCF._compute_item_score(user_id)
item_scores_itemknn
# Out:
# array([[ 1.5751346, 15.212906 , 15.825802 , ...,  0.       ,  0.       ,
#          0.       ]], dtype=float32)

# %%
item_scores_puresvd = pureSVD._compute_item_score(user_id)
item_scores_puresvd
# Out:
# array([0.00926975, 0.85355353, 0.85023683, ..., 0.        , 0.        ,
#        0.        ], dtype=float32)

# %% [markdown]
# As you can see, we provide a score for every item in the dataset in both recommenders.
#
# Remember that after calculating these scores, we sort them and take the n-most relevant ones.
#
# Again we use a weight

# %%
alpha = 0.7

new_item_scores = alpha * item_scores_itemknn + (1 - alpha) * item_scores_puresvd
new_item_scores
# Out:
# array([[ 1.1053752, 10.9051   , 11.333132 , ...,  0.       ,  0.       ,
#          0.       ]], dtype=float32)

# %% [markdown]
# Now we create a recommeder class. Note that again we can build a hybrid combining any number of models

# %%
from Recommenders.BaseRecommender import BaseRecommender

class ScoresHybridRecommender(BaseRecommender):
    """ ScoresHybridRecommender
    Hybrid of two prediction scores R = R1*alpha + R2*(1-alpha)

    """

    RECOMMENDER_NAME = "ScoresHybridRecommender"

    def __init__(self, URM_train, recommender_1, recommender_2):
        super(ScoresHybridRecommender, self).__init__(URM_train)

        self.URM_train = sps.csr_matrix(URM_train)
        self.recommender_1 = recommender_1
        self.recommender_2 = recommender_2
        
        
    def fit(self, alpha = 0.5):
        self.alpha = alpha      


    def _compute_item_score(self, user_id_array, items_to_compute):
        
        # In a simple extension this could be a loop over a list of pretrained recommender objects
        item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
        item_weights_2 = self.recommender_2._compute_item_score(user_id_array)

        item_weights = item_weights_1*self.alpha + item_weights_2*(1-self.alpha)

        return item_weights

# %%
scoreshybridrecommender = ScoresHybridRecommender(URM_train, itemKNNCF, pureSVD)
scoreshybridrecommender.fit(alpha = 0.5)

result_df, _ = evaluator_validation.evaluateRecommender(recommender_object)
result_df
# Out:
# ScoresHybridRecommender: URM Detected 56 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 69646 (100.0%) in 1.65 min. Users per second: 702
#        PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 5       0.215409                 0.226058  0.091519  0.138712    0.144573
# 10      0.190391                 0.237977  0.155324  0.100197    0.121481
# 15      0.173678                 0.263674  0.205994  0.081665    0.117453
#
#              MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                        ...
# 5       0.390276  0.174329   0.12846   0.63135       0.52256  ...
# 10      0.408667  0.191664  0.171079  0.766074      0.630482  ...
# 15      0.413189  0.208232  0.188461  0.823077      0.685336  ...
#
#        COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
# cutoff
# 5                   0.112817       0.99668              0.629254
# 10                  0.144649       0.99668              0.763531
# 15                  0.165247       0.99668              0.820344
#
#        DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
# cutoff
# 5            0.020315        7.935157                   0.992767
# 10           0.023811        8.224321                   0.994692
# 15           0.026533        8.411696                   0.995614
#
#        RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
# cutoff
# 5                  0.104375              0.700704                 1.742755
# 10                 0.122335              0.726238                  1.65526
# 15                  0.13632              0.742784                 1.592826
#
#        RATIO_NOVELTY
# cutoff
# 5           0.045313
# 10          0.091417
# 15          0.138028
#
# [3 rows x 25 columns]

# %% [markdown]
# # Models with rating prediction vs ranking loss functions
#
# Sometimes we have models that optimize different loss functions, one BPR (ranking) and another rating prediction (MSE). For instance:
# - SLIMBPR and SLIM EN/MSE
# - FunkSVD and MFBPR
# - ...
#
# This brings another important problem, for rank-based models there is no clear meaning for the *absolute value* of the prediction. A value of 15.245 may be low or high, depending on the *other* values.
#
# In those cases it becomes essential to include a *normalization* on the weights, to ensure that the values are, at least, in the same range for all models. Many normalizations can be used: min/max, l1, l2, other nonlinear functions (sigmoid, ...)

# %%
from Recommenders.MatrixFactorization.Cython.MatrixFactorization_Cython import MatrixFactorization_FunkSVD_Cython

funk_svd_recommender = MatrixFactorization_FunkSVD_Cython(URM_train)
funk_svd_recommender.fit(epochs=200)
# Out:
# MatrixFactorization_FunkSVD_Cython_Recommender: URM Detected 56 ( 0.5%) items with no interactions.
# FUNK_SVD: Processed 6401000 (100.0%) in 7.10 sec. MSE loss 2.15E+00. Sample per second: 901174
# FUNK_SVD: Epoch 1 of 200. Elapsed time 6.22 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 6.08 sec. MSE loss 1.13E+00. Sample per second: 1052665
# FUNK_SVD: Epoch 2 of 200. Elapsed time 12.20 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 6.09 sec. MSE loss 1.13E+00. Sample per second: 1051602
# FUNK_SVD: Epoch 3 of 200. Elapsed time 18.21 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 5.73 sec. MSE loss 1.13E+00. Sample per second: 1117830
# FUNK_SVD: Epoch 4 of 200. Elapsed time 23.85 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 6.67 sec. MSE loss 1.12E+00. Sample per second: 959746
# FUNK_SVD: Epoch 5 of 200. Elapsed time 29.79 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 6.50 sec. MSE loss 1.12E+00. Sample per second: 984937
# FUNK_SVD: Epoch 6 of 200. Elapsed time 35.62 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 6.44 sec. MSE loss 1.12E+00. Sample per second: 993685
# FUNK_SVD: Epoch 7 of 200. Elapsed time 41.56 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 6.65 sec. MSE loss 1.12E+00. Sample per second: 962937
# FUNK_SVD: Epoch 8 of 200. Elapsed time 47.77 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 6.90 sec. MSE loss 1.11E+00. Sample per second: 927636
# FUNK_SVD: Epoch 9 of 200. Elapsed time 54.02 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 7.38 sec. MSE loss 1.11E+00. Sample per second: 867151
# FUNK_SVD: Epoch 10 of 200. Elapsed time 1.01 min
# FUNK_SVD: Processed 6401000 (100.0%) in 6
93 min
# FUNK_SVD: Processed 6401000 (100.0%) in 9.08 sec. MSE loss 1.00E+00. Sample per second: 704617
# FUNK_SVD: Epoch 187 of 200. Elapsed time 19.07 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.24 sec. MSE loss 1.00E+00. Sample per second: 776988
# FUNK_SVD: Epoch 188 of 200. Elapsed time 19.21 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.55 sec. MSE loss 1.00E+00. Sample per second: 748865
# FUNK_SVD: Epoch 189 of 200. Elapsed time 19.34 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.72 sec. MSE loss 1.00E+00. Sample per second: 828898
# FUNK_SVD: Epoch 190 of 200. Elapsed time 19.46 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.34 sec. MSE loss 1.00E+00. Sample per second: 767063
# FUNK_SVD: Epoch 191 of 200. Elapsed time 19.59 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.47 sec. MSE loss 9.99E-01. Sample per second: 856760
# FUNK_SVD: Epoch 192 of 200. Elapsed time 19.71 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.03 sec. MSE loss 1.00E+00. Sample per second: 797064
# FUNK_SVD: Epoch 193 of 200. Elapsed time 19.84 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.66 sec. MSE loss 9.99E-01. Sample per second: 835613
# FUNK_SVD: Epoch 194 of 200. Elapsed time 19.96 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.67 sec. MSE loss 9.98E-01. Sample per second: 738339
# FUNK_SVD: Epoch 195 of 200. Elapsed time 20.10 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.55 sec. MSE loss 1.00E+00. Sample per second: 748794
# FUNK_SVD: Epoch 196 of 200. Elapsed time 20.23 min
# FUNK_SVD: Processed 6401000 (100.0%) in 9.38 sec. MSE loss 1.00E+00. Sample per second: 682667
# FUNK_SVD: Epoch 197 of 200. Elapsed time 20.37 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.90 sec. MSE loss 9.99E-01. Sample per second: 719389
# FUNK_SVD: Epoch 198 of 200. Elapsed time 20.52 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.62 sec. MSE loss 9.97E-01. Sample per second: 742130
# FUNK_SVD: Epoch 199 of 200. Elapsed time 20.65 min
# FUNK_SVD: Processed 6401000 (100.0%) in 9.04 sec. MSE loss 9.99E-01. Sample per second: 708310
# FUNK_SVD: Epoch 200 of 200. Elapsed time 20.79 min
# FUNK_SVD: Terminating at epoch 200. Elapsed time 20.79 min

# %%
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython

slim_bpr_recommender = SLIM_BPR_Cython(URM_train)
slim_bpr_recommender.fit(epochs=200)
# Out:
# SLIM_BPR_Recommender: URM Detected 56 ( 0.5%) items with no interactions.
# Unable to read memory status: list index out of range
# SLIM_BPR_Recommender: Automatic selection of fastest train mode. Unable to get current RAM status, you may be using a non-Linux operating system. Using dense matrix.
# Processed 69878 (100.0%) in 1.33 sec. BPR loss is 3.52E-04. Sample per second: 52400
# SLIM_BPR_Recommender: Epoch 1 of 200. Elapsed time 0.60 sec
# Processed 69878 (100.0%) in 0.98 sec. BPR loss is 1.15E-03. Sample per second: 70998
# SLIM_BPR_Recommender: Epoch 2 of 200. Elapsed time 1.26 sec
# Processed 69878 (100.0%) in 1.70 sec. BPR loss is 1.91E-03. Sample per second: 41101
# SLIM_BPR_Recommender: Epoch 3 of 200. Elapsed time 1.97 sec
# Processed 69878 (100.0%) in 1.65 sec. BPR loss is 2.74E-03. Sample per second: 42444
# SLIM_BPR_Recommender: Epoch 4 of 200. Elapsed time 2.92 sec
# Processed 69878 (100.0%) in 1.26 sec. BPR loss is 3.54E-03. Sample per second: 55501
# SLIM_BPR_Recommender: Epoch 5 of 200. Elapsed time 3.53 sec
# Processed 69878 (100.0%) in 1.04 sec. BPR loss is 4.34E-03. Sample per second: 67325
# SLIM_BPR_Recommender: Epoch 6 of 200. Elapsed time 4.31 sec
# Processed 69878 (100.0%) in 0.84 sec. BPR loss is 5.15E-03. Sample per second: 82786
# SLIM_BPR_Recommender: Epoch 7 of 200. Elapsed time 5.11 sec
# Processed 69878 (100.0%) in 1.64 sec. BPR loss is 5.96E-03. Sample per second: 42691
# SLIM_BPR_Recommender: Epoch 8 of 200. Elapsed time 5.91 sec
# Processed 69878 (100.0%) in 1.35 sec. BPR loss is 6.86E-03. Sample per second: 51757
# SLIM_BPR_Recommender: Epoch 9 of 200. Elapsed time 6.62 sec
# Processed 69878 (100.0%) in 1.02 sec. BPR loss is 7.54E-03. Sample per second: 68770
# SLIM_BPR_Recommender: Epoch 10 of 200. Elapsed time 7.29 sec
# Processed 69878 (100.0%) in 0.97 sec. BPR loss is 8.19E-03. Sample per second: 72317
# SLIM_BPR_Recommender: Epoch 11 of 200. Elapsed time 8.24 sec
# Processed 69878 (100.0%) in 1.58 sec. BPR loss is 9.26E-03. Sample per second: 44113
# SLIM_BPR_Recommender: Epoch 12 of 200. Elapsed time 8.85 sec
# Processed 69878 (100.0%) in 1.47 sec. BPR loss is 9.89E-03. Sample per second: 47666
# SLIM_BPR_Recommender: Epoch 13 of 200. Elapsed time 9.74 sec
# Processed 69878 (100.0%) in 1.04 sec. BPR loss is 1.06E-02. Sample per second: 67161
# SLIM_BPR_Recommender: Epoch 14 of 200. Elapsed time 10.31 sec
# Processed 69878 (100.0%) in 0.74 sec. BPR loss is 1.13E-02. Sample per second: 94072
# SLIM_BPR_Recommender: Epoch 15 of 200. Elapsed time 11.01 sec
# Processed 69878 (100.0%) in 1.57 sec. BPR loss is 1.24E-02. Sample per second: 44480
# SLIM_BPR_Recommender: Epoch 16 of 200. Elapsed time 11.84 sec
# Processed 69878 (100.0%) in 1.38 sec. BPR loss is 1.33E-02. Sample per second: 50516
# SLIM_BPR_Recommender: Epoch 17 of 200. Elapsed time 12.65 sec
# Processed 69878 (100.0%) in 0.99 sec. BPR loss is 1.39E-02. Sample per second: 70211
# SLIM_BPR_Recommender: Epoch 18 of 200. Elapsed time 13.27 sec
# Processed 69878 (100.0%) in 1.63 sec. BPR loss is 1.47E-02. Sample per second: 42839
# SLIM_BPR_Recommender: Epoch 19 of 200. Elapsed time 13.90 sec
# Processed 69878 (100.0%) in 1.35 sec. BPR loss is 1.54E-02. Sample per second: 51833
# SLIM_BPR_Recommender: Epoch 20 of 200. Elapsed time 14.62 sec
# Processed 69878 (100.0%) in 1.15 sec. BPR loss is 1.62E-02. Sample per second: 60661
# SLIM_BPR_Recommender: Epoch 21 of 200. Elapsed time 15.42 sec
# Processed 69878 (100.0%) in 0.81 sec. BPR loss is 1.73E-02. Sample per second: 86339
# SLIM_BPR_Recommender: Epoch 22 of 200. Elapsed time 16.08 sec
# Processed 69878 (100.0%) in 1.70 sec. BPR loss is 1.77E-02. Sample per second: 41197
# SLIM_BPR_Recommender: Epoch 23 of 200. Elapsed time 16.97 sec
# Processed 69878 (100.0%) in 1.55 sec. BPR loss is 1.84E-02. Sample per second: 44997
# SLIM_BPR_Recommender: Epoch 24 of 200. Elapsed time 17.82 sec
# Processed 69878 (100.0%) in 1.26 sec. BPR loss is 1.96E-02. Sample per second: 55313
# SLIM_BPR_Recommender: Epoch 25 of 200. Elapsed time 18.53 sec
# Processed 69878 (100.0%) in 0.90 sec. BPR loss is 2.00E-02. Sample per second: 77278
# SLIM_BPR_Recommender: Epoch 26 of 200. Elapsed time 19.18 sec
# Processed 69878 (100.0%) in 1.65 sec. BPR loss is 2.08E-02. Sample per second: 42324
# SLIM_BPR_Recommender: Epoch 27 of 200. Elapsed time 19.92 sec
# Processed 69878 (100.0%) in 1.42 sec. BPR loss is 2.14E-02. Sample per second: 49129
# SLIM_BPR_Recommender: Epoch 28 of 200. Elapsed time 20.69 sec
# Processed 69878 (100.0%) in 1.04 sec. BPR loss is 2.22E-02. Sample per second: 67044
# SLIM_BPR_Recommender: Epoch 29 of 200. Elapsed time 21.31 sec
# Processed 69878 (100.0%) in 0.67 sec. BPR loss is 2.32E-02. Sample per second: 104381
# SLIM_BPR_Recommender: Epoch 30 of 200. Elapsed time 21.94 sec
# Processed 69878 (100.0%) in 1.29 sec. BPR loss is 2.38E-02. Sample per second: 54011
# SLIM_BPR_Recommender: Epoch 31 of 200. Elapsed time 22.56 sec
# Processed 69878 (100.0%) in 0.91 sec. BPR loss is 2.47E-02. Sample per second: 76514
# SLIM_BPR_Recommender: Epoch 32 of 200. Elapsed time 23.18 sec
# Processed 69878 (100.0%) in 1.65 sec. BPR loss is 2.53E-02. Sample per second: 42372
# SLIM_BPR_Recommender: Epoch 33 of 200. Elapsed time 23.92 sec
# Processed 69878 (100.0%) in 1.45 sec. BPR loss is 2.66E-02. Sample per second: 48258
# SLIM_BPR_Recommender: Epoch 34 of 200. Elapsed time 24.72 sec
# Processed 69878 (100.0%) in 1.22 sec. BPR loss is 2.69E-02. Sample per second: 57418
# SLIM_BPR_Recommender: Epoch 35 of 200. Elapsed time 25.49 sec
# Processed 69878 (100.0%) in 0.85 sec. BPR loss is 2.76E-02. Sample per second: 81734
# SLIM_BPR_Recommender: Epoch 36 of 200. Elapsed time 26.13 sec
# Processed 69878 (100.0%) in 1.42 sec. BPR loss is 2.85E-02. Sample per second: 49011
# SLIM_BPR_Recommender: Epoch 37 of 200. Elapsed time 26.70 sec
# Processed 69878 (100.0%) in 1.10 sec. BPR loss is 2.93E-02. Sample per second: 63616
# SLIM_BPR_Recommender: Epoch 38 of 200. Elapsed time 27.37 sec
# Processed 69878 (100.0%) in 0.71 sec. BPR loss is 3.05E-02. Sample per second: 98787
# SLIM_BPR_Recommender: Epoch 39 of 200. Elapsed time 27.98 sec
# Processed 69878 (100.0%) in 1.36 sec. BPR loss is 3.08E-02. Sample per second: 51331
# SLIM_BPR_Recommender: Epoch 40 of 200. Elapsed time 28.63 sec
# Processed 69878 (100.0%) in 1.00 sec. BPR loss is 3.14E-02. Sample per second: 70215
# SLIM_BPR_Recommender: Epoch 41 of 200. Elapsed time 29.27 sec
# Processed 69878 (100.0%) in 1.58 sec. BPR loss is 3.21E-02. Sample per second: 44111
# SLIM_BPR_Recommender: Epoch 42 of 200. Elapsed time 29.85 sec
# Processed 69878 (100.0%) in 1.23 sec. BPR loss is 3.25E-02. Sample per second: 56810
# SLIM_BPR_Recommender: Epoch 43 of 200. Elapsed time 30.50 sec
# Processed 69878 (100.0%) in 0.85 sec. BPR loss is 3.37E-02. Sample per second: 82388
# SLIM_BPR_Recommender: Epoch 44 of 200. Elapsed time 31.12 sec
# Processed 69878 (100.0%) in 1.53 sec. BPR loss is 3.46E-02. Sample per second: 45523
# SLIM_BPR_Recommender: Epoch 45 of 200. Elapsed time 31.80 sec
# Processed 69878 (100.0%) in 1.17 sec. BPR loss is 3.56E-02. Sample per second: 59732
# SLIM_BPR_Recommender: Epoch 46 of 200. Elapsed time 32.44 sec
# Processed 69878 (100.0%) in 0.83 sec. BPR loss is 3.61E-02. Sample per second: 83960
# SLIM_BPR_Recommender: Epoch 47 of 200. Elapsed time 33.10 sec
# Processed 69878 (100.0%) in 1.48 sec. BPR loss is 3.68E-02. Sample per second: 47112
# SLIM_BPR_Recommender: Epoch 48 of 200. Elapsed time 33.75 sec
# Processed 69878 (100.0%) in 1.12 sec. BPR loss is 3.78E-02. Sample per second: 62544
# SLIM_BPR_Recommender: Epoch 49 of 200. Elapsed time 34.39 sec
# Processed 69878 (100.0%) in 0.71 sec. BPR loss is 3.82E-02. Sample per second: 97774
# SLIM_BPR_Recommender: Epoch 50 of 200. Elapsed time 34.98 sec
# Processed 69878 (100.0%) in 1.31 sec. BPR loss is 3.93E-02. Sample per second: 53426
# SLIM_BPR_Recommender: Epoch 51 of 200. Elapsed time 35.58 sec
# Processed 69878 (100.0%) in 0.93 sec. BPR loss is 3.95E-02. Sample per second: 75510
# SLIM_BPR_Recommender: Epoch 52 of 200. Elapsed time 36.20 sec
# Processed 69878 (100.0%) in 1.50 sec. BPR loss is 4.06E-02. Sample per second: 46547
# SLIM_BPR_Recommender: Epoch 53 of 200. Elapsed time 36.77 sec
# Processed 69878 (100.0%) in 1.18 sec. BPR loss is 4.17E-02. Sample per second: 59468
# SLIM_BPR_Recommender: Epoch 54 of 200. Elapsed time 37.45 sec
# Processed 69878 (100.0%) in 0.74 sec. BPR loss is 4.18E-02. Sample per second: 93916
# SLIM_BPR_Recommender: Epoch 55 of 200. Elapsed time 38.01 sec
# Processed 69878 (100.0%) in 1.38 sec. BPR loss is 4.25E-02. Sample per second: 50783
# SLIM_BPR_Recommender: Epoch 56 of 200. Elapsed time 38.65 sec
# Processed 69878 (100.0%) in 0.98 sec. BPR loss is 4.36E-02. Sample per second: 70871
# SLIM_BPR_Recommender: Epoch 57 of 200. Elapsed time 39.26 sec
# Processed 69878 (100.0%) in 1.60 sec. BPR loss is 4.48E-02. Sample per second: 43621
# SLIM_BPR_Recommender: Epoch 58 of 200. Elapsed time 39.87 sec
# Processed 69878 (100.0%) in 1.19 sec. BPR loss is 4.52E-02. Sample per second: 58678
# SLIM_BPR_Recommender: Epoch 59 of 200. Elapsed time 40.46 sec
# Processed 69878 (100.0%) in 0.81 sec. BPR loss is 4.59E-02. Sample per second: 86085
# SLIM_BPR_Recommender: Epoch 60 of 200. Elapsed time 41.08 sec
# Processed 69878 (100.0%) in 1.40 sec. BPR loss is 4.63E-02. Sample per second: 50032
# SLIM_BPR_Recommender: Epoch 61 of 200. Elapsed time 41.67 sec
# Processed 69878 (100.0%) in 0.98 sec. BPR loss is 4.68E-02. Sample per second: 71515
# SLIM_BPR_Recommender: Epoch 62 of 200. Elapsed time 42.25 sec
# Processed 69878 (100.0%) in 1.62 sec. BPR loss is 4.76E-02. Sample per second: 43054
# SLIM_BPR_Recommender: Epoch 63 of 200. Elapsed time 42.89 sec
# Processed 69878 (100.0%) in 1.18 sec. BPR loss is 4.81E-02. Sample per second: 59167
# SLIM_BPR_Recommender: Epoch 64 of 200. Elapsed time 43.45 sec
# Processed 69878 (100.0%) in 0.80 sec. BPR loss is 4.89E-02. Sample per second: 86916
# SLIM_BPR_Recommender: Epoch 65 of 200. Elapsed time 44.07 sec
# Processed 69878 (100.0%) in 1.42 sec. BPR loss is 5.02E-02. Sample per second: 49178
# SLIM_BPR_Recommender: Epoch 66 of 200. Elapsed time 44.69 sec
# Processed 69878 (100.0%) in 0.99 sec. BPR loss is 5.22E-02. Sample per second: 70483
# SLIM_BPR_Recommender: Epoch 67 of 200. Elapsed time 45.26 sec
# Processed 69878 (100.0%) in 1.72 sec. BPR loss is 5.18E-02. Sample per second: 40738
# SLIM_BPR_Recommender: Epoch 68 of 200. Elapsed time 45.99 sec
# Processed 69878 (100.0%) in 1.41 sec. BPR loss is 5.18E-02. Sample per second: 49517
# SLIM_BPR_Recommender: Epoch 69 of 200. Elapsed time 46.68 sec
# Processed 69878 (100.0%) in 1.11 sec. BPR loss is 5.23E-02. Sample per second: 63006
# SLIM_BPR_Recommender: Epoch 70 of 200. Elapsed time 47.38 sec
# Processed 69878 (100.0%) in 0.80 sec. BPR loss is 5.39E-02. Sample per second: 87190
# SLIM_BPR_Recommender: Epoch 71 of 200. Elapsed time 48.07 sec
# Processed 69878 (100.0%) in 1.36 sec. BPR loss is 5.53E-02. Sample per second: 51491
# SLIM_BPR_Recommender: Epoch 72 of 200. Elapsed time 48.63 sec
# Processed 69878 (100.0%) in 1.15 sec. BPR loss is 5.52E-02. Sample per second: 60507
# SLIM_BPR_Recommender: Epoch 73 of 200. Elapsed time 49.43 sec
# Processed 69878 (100.0%) in 0.78 sec. BPR loss is 5.60E-02. Sample per second: 89566
# SLIM_BPR_Recommender: Epoch 74 of 200. Elapsed time 50.05 sec
# Processed 69878 (100.0%) in 1.42 sec. BPR loss is 5.58E-02. Sample per second: 49137
# SLIM_BPR_Recommender: Epoch 75 of 200. Elapsed time 50.69 sec
# Processed 69878 (100.0%) in 1.20 sec. BPR loss is 5.70E-02. Sample per second: 58381
# SLIM_BPR_Recommender: Epoch 76 of 200. Elapsed time 51.47 sec
# Processed 69878 (100.0%) in 0.96 sec. BPR loss is 5.83E-02. Sample per second: 72554
# SLIM_BPR_Recommender: Epoch 77 of 200. Elapsed time 52.23 sec
# Processed 69878 (100.0%) in 1.59 sec. BPR loss is 5.89E-02. Sample per second: 44001
# SLIM_BPR_Recommender: Epoch 78 of 200. Elapsed time 52.86 sec
# Processed 69878 (100.0%) in 1.30 sec. BPR loss is 5.91E-02. Sample per second: 53671
# SLIM_BPR_Recommender: Epoch 79 of 200. Elapsed time 53.57 sec
# Processed 69878 (100.0%) in 1.03 sec. BPR loss is 6.03E-02. Sample per second: 67919
# SLIM_BPR_Recommender: Epoch 80 of 200. Elapsed time 54.30 sec
# Processed 69878 (100.0%) in 0.83 sec. BPR loss is 6.09E-02. Sample per second: 84371
# SLIM_BPR_Recommender: Epoch 81 of 200. Elapsed time 55.10 sec
# Processed 69878 (100.0%) in 1.48 sec. BPR loss is 6.20E-02. Sample per second: 47082
# SLIM_BPR_Recommender: Epoch 82 of 200. Elapsed time 55.76 sec
# Processed 69878 (100.0%) in 1.12 sec. BPR loss is 6.15E-02. Sample per second: 62329
# SLIM_BPR_Recommender: Epoch 83 of 200. Elapsed time 56.39 sec
# Processed 69878 (100.0%) in 0.70 sec. BPR loss is 6.33E-02. Sample per second: 99806
# SLIM_BPR_Recommender: Epoch 84 of 200. Elapsed time 56.97 sec
# Processed 69878 (100.0%) in 1.57 sec. BPR loss is 6.39E-02. Sample per second: 44539
# SLIM_BPR_Recommender: Epoch 85 of 200. Elapsed time 57.84 sec
# Processed 69878 (100.0%) in 1.24 sec. BPR loss is 6.45E-02. Sample per second: 56451
# SLIM_BPR_Recommender: Epoch 86 of 200. Elapsed time 58.51 sec
# Processed 69878 (100.0%) in 0.97 sec. BPR loss is 6.45E-02. Sample per second: 71576
# SLIM_BPR_Recommender: Epoch 87 of 200. Elapsed time 59.25 sec
# Processed 69878 (100.0%) in 1.67 sec. BPR loss is 6.63E-02. Sample per second: 41803
# SLIM_BPR_Recommender: Epoch 88 of 200. Elapsed time 59.94 sec
# Processed 69878 (100.0%) in 1.54 sec. BPR loss is 6.71E-02. Sample per second: 45504
# SLIM_BPR_Recommender: Epoch 89 of 200. Elapsed time 1.01 min
# Processed 69878 (100.0%) in 1.16 sec. BPR loss is 6.78E-02. Sample per second: 60288
# SLIM_BPR_Recommender: Epoch 90 of 200. Elapsed time 1.02 min
# Processed 69878 (100.0%) in 0.76 sec. BPR loss is 6.73E-02. Sample per second: 92063
# SLIM_BPR_Recommender: Epoch 91 of 200. Elapsed time 1.03 min
# Processed 69878 (100.0%) in 1.36 sec. BPR loss is 6.92E-02. Sample per second: 51267
# SLIM_BPR_Recommender: Epoch 92 of 200. Elapsed time 1.04 min
# Processed 69878 (100.0%) in 0.99 sec. BPR loss is 7.01E-02. Sample per second: 70585
# SLIM_BPR_Recommender: Epoch 93 of 200. Elapsed time 1.05 min
# Processed 69878 (100.0%) in 1.61 sec. BPR loss is 7.08E-02. Sample per second: 43365
# SLIM_BPR_Recommender: Epoch 94 of 200. Elapsed time 1.06 min
# Processed 69878 (100.0%) in 1.29 sec. BPR loss is 7.03E-02. Sample per second: 54324
# SLIM_BPR_Recommender: Epoch 95 of 200. Elapsed time 1.08 min
# Processed 69878 (100.0%) in 0.88 sec. BPR loss is 7.20E-02. Sample per second: 79112
# SLIM_BPR_Recommender: Epoch 96 of 200. Elapsed time 1.09 min
# Processed 69878 (100.0%) in 1.54 sec. BPR loss is 7.19E-02. Sample per second: 45458
# SLIM_BPR_Recommender: Epoch 97 of 200. Elapsed time 1.10 min
# Processed 69878 (100.0%) in 1.33 sec. BPR loss is 7.30E-02. Sample per second: 52658
# SLIM_BPR_Recommender: Epoch 98 of 200. Elapsed time 1.11 min
# Processed 69878 (100.0%) in 0.91 sec. BPR loss is 7.41E-02. Sample per second: 76454
# SLIM_BPR_Recommender: Epoch 99 of 200. Elapsed time 1.12 min
# Processed 69878 (100.0%) in 1.57 sec. BPR loss is 7.48E-02. Sample per second: 44575
# SLIM_BPR_Recommender: Epoch 100 of 200. Elapsed time 1.13 min
# Processed 69878 (100.0%) in 1.20 sec. BPR loss is 7.62E-02. Sample per second: 57896
# SLIM_BPR_Recommender: Epoch 101 of 200. Elapsed time 1.14 min
# Processed 69878 (100.0%) in 0.88 sec. BPR loss is 7.66E-02. Sample per second: 79372
# SLIM_BPR_Recommender: Epoch 102 of 200. Elapsed time 1.15 min
# Processed 69878 (100.0%) in 1.62 sec. BPR loss is 7.59E-02. Sample per second: 43128
# SLIM_BPR_Recommender: Epoch 103 of 200. Elapsed time 1.16 min
# Processed 69878 (100.0%) in 1.19 sec. BPR loss is 7.66E-02. Sample per second: 58561
# SLIM_BPR_Recommender: Epoch 104 of 200. Elapsed time 1.17 min
# Processed 69878 (100.0%) in 0.93 sec. BPR loss is 7.88E-02. Sample per second: 75206
# SLIM_BPR_Recommender: Epoch 105 of 200. Elapsed time 1.19 min
# Processed 69878 (100.0%) in 1.54 sec. BPR loss is 7.81E-02. Sample per second: 45283
# SLIM_BPR_Recommender: Epoch 106 of 200. Elapsed time 1.20 min
# Processed 69878 (100.0%) in 1.19 sec. BPR loss is 7.95E-02. Sample per second: 58719
# SLIM_BPR_Recommender: Epoch 107 of 200. Elapsed time 1.21 min
# Processed 69878 (100.0%) in 0.82 sec. BPR loss is 7.89E-02. Sample per second: 85342
# SLIM_BPR_Recommender: Epoch 108 of 200. Elapsed time 1.22 min
# Processed 69878 (100.0%) in 1.46 sec. BPR loss is 8.15E-02. Sample per second: 47768
# SLIM_BPR_Recommender: Epoch 109 of 200. Elapsed time 1.23 min
# Processed 69878 (100.0%) in 1.16 sec. BPR loss is 8.23E-02. Sample per second: 60355
# SLIM_BPR_Recommender: Epoch 110 of 200. Elapsed time 1.24 min
# Processed 69878 (100.0%) in 0.87 sec. BPR loss is 8.21E-02. Sample per second: 80052
# SLIM_BPR_Recommender: Epoch 111 of 200. Elapsed time 1.25 min
# Processed 69878 (100.0%) in 1.49 sec. BPR loss is 8.34E-02. Sample per second: 46961
# SLIM_BPR_Recommender: Epoch 112 of 200. Elapsed time 1.26 min
# Processed 69878 (100.0%) in 1.16 sec. BPR loss is 8.32E-02. Sample per second: 60271
# SLIM_BPR_Recommender: Epoch 113 of 200. Elapsed time 1.27 min
# Processed 69878 (100.0%) in 0.81 sec. BPR loss is 8.38E-02. Sample per second: 86665
# SLIM_BPR_Recommender: Epoch 114 of 200. Elapsed time 1.28 min
# Processed 69878 (100.0%) in 1.43 sec. BPR loss is 8.51E-02. Sample per second: 48858
# SLIM_BPR_Recommender: Epoch 115 of 200. Elapsed time 1.30 min
# Processed 69878 (100.0%) in 1.05 sec. BPR loss is 8.68E-02. Sample per second: 66670
# SLIM_BPR_Recommender: Epoch 116 of 200. Elapsed time 1.31 min
# Processed 69878 (100.0%) in 0.66 sec. BPR loss is 8.60E-02. Sample per second: 105708
# SLIM_BPR_Recommender: Epoch 117 of 200. Elapsed time 1.32 min
# Processed 69878 (100.0%) in 1.24 sec. BPR loss is 8.73E-02. Sample per second: 56354
# SLIM_BPR_Recommender: Epoch 118 of 200. Elapsed time 1.33 min
# Processed 69878 (100.0%) in 0.82 sec. BPR loss is 8.78E-02. Sample per second: 85116
# SLIM_BPR_Recommender: Epoch 119 of 200. Elapsed time 1.33 min
# Processed 69878 (100.0%) in 1.46 sec. BPR loss is 8.73E-02. Sample per second: 47726
# SLIM_BPR_Recommender: Epoch 120 of 200. Elapsed time 1.35 min
# Processed 69878 (100.0%) in 1.06 sec. BPR loss is 8.91E-02. Sample per second: 65792
# SLIM_BPR_Recommender: Epoch 121 of 200. Elapsed time 1.36 min
# Processed 69878 (100.0%) in 0.67 sec. BPR loss is 8.96E-02. Sample per second: 104601
# SLIM_BPR_Recommender: Epoch 122 of 200. Elapsed time 1.37 min
# Processed 69878 (100.0%) in 1.36 sec. BPR loss is 9.05E-02. Sample per second: 51459
# SLIM_BPR_Recommender: Epoch 123 of 200. Elapsed time 1.38 min
# Processed 69878 (100.0%) in 0.94 sec. BPR loss is 9.21E-02. Sample per second: 74187
# SLIM_BPR_Recommender: Epoch 124 of 200. Elapsed time 1.39 min
# Processed 69878 (100.0%) in 1.52 sec. BPR loss is 9.17E-02. Sample per second: 45855
# SLIM_BPR_Recommender: Epoch 125 of 200. Elapsed time 1.40 min
# Processed 69878 (100.0%) in 1.29 sec. BPR loss is 9.32E-02. Sample per second: 54116
# SLIM_BPR_Recommender: Epoch 126 of 200. Elapsed time 1.41 min
# Processed 69878 (100.0%) in 1.00 sec. BPR loss is 9.26E-02. Sample per second: 69459
# SLIM_BPR_Recommender: Epoch 127 of 200. Elapsed time 1.42 min
# Processed 69878 (100.0%) in 1.21 sec. BPR loss is 9.56E-02. Sample per second: 57555
# SLIM_BPR_Recommender: Epoch 128 of 200. Elapsed time 1.44 min
# Processed 69878 (100.0%) in 0.98 sec. BPR loss is 9.41E-02. Sample per second: 71418
# SLIM_BPR_Recommender: Epoch 129 of 200. Elapsed time 1.45 min
# Processed 69878 (100.0%) in 1.75 sec. BPR loss is 9.42E-02. Sample per second: 40007
# SLIM_BPR_Recommender: Epoch 130 of 200. Elapsed time 1.47 min
# Processed 69878 (100.0%) in 1.36 sec. BPR loss is 9.57E-02. Sample per second: 51265
# SLIM_BPR_Recommender: Epoch 131 of 200. Elapsed time 1.48 min
# Processed 69878 (100.0%) in 1.03 sec. BPR loss is 9.67E-02. Sample per second: 67849
# SLIM_BPR_Recommender: Epoch 132 of 200. Elapsed time 1.49 min
# Processed 69878 (100.0%) in 0.74 sec. BPR loss is 9.67E-02. Sample per second: 93758
# SLIM_BPR_Recommender: Epoch 133 of 200. Elapsed time 1.50 min
# Processed 69878 (100.0%) in 1.42 sec. BPR loss is 9.84E-02. Sample per second: 49243
# SLIM_BPR_Recommender: Epoch 134 of 200. Elapsed time 1.51 min
# Processed 69878 (100.0%) in 1.02 sec. BPR loss is 9.92E-02. Sample per second: 68742
# SLIM_BPR_Recommender: Epoch 135 of 200. Elapsed time 1.52 min
# Processed 69878 (100.0%) in 0.68 sec. BPR loss is 9.85E-02. Sample per second: 102112
# SLIM_BPR_Recommender: Epoch 136 of 200. Elapsed time 1.53 min
# Processed 69878 (100.0%) in 1.30 sec. BPR loss is 1.00E-01. Sample per second: 53559
# SLIM_BPR_Recommender: Epoch 137 of 200. Elapsed time 1.54 min
# Processed 69878 (100.0%) in 0.92 sec. BPR loss is 1.01E-01. Sample per second: 76274
# SLIM_BPR_Recommender: Epoch 138 of 200. Elapsed time 1.55 min
# Processed 69878 (100.0%) in 1.62 sec. BPR loss is 1.01E-01. Sample per second: 43052
# SLIM_BPR_Recommender: Epoch 139 of 200. Elapsed time 1.56 min
# Processed 69878 (100.0%) in 1.47 sec. BPR loss is 1.03E-01. Sample per second: 47475
# SLIM_BPR_Recommender: Epoch 140 of 200. Elapsed time 1.58 min
# Processed 69878 (100.0%) in 1.24 sec. BPR loss is 1.02E-01. Sample per second: 56209
# SLIM_BPR_Recommender: Epoch 141 of 200. Elapsed time 1.59 min
# Processed 69878 (100.0%) in 1.11 sec. BPR loss is 1.03E-01. Sample per second: 62730
# SLIM_BPR_Recommender: Epoch 142 of 200. Elapsed time 1.61 min
# Processed 69878 (100.0%) in 0.83 sec. BPR loss is 1.05E-01. Sample per second: 84361
# SLIM_BPR_Recommender: Epoch 143 of 200. Elapsed time 1.62 min
# Processed 69878 (100.0%) in 1.48 sec. BPR loss is 1.05E-01. Sample per second: 47112
# SLIM_BPR_Recommender: Epoch 144 of 200. Elapsed time 1.63 min
# Processed 69878 (100.0%) in 1.34 sec. BPR loss is 1.05E-01. Sample per second: 52033
# SLIM_BPR_Recommender: Epoch 145 of 200. Elapsed time 1.64 min
# Processed 69878 (100.0%) in 1.09 sec. BPR loss is 1.06E-01. Sample per second: 64093
# SLIM_BPR_Recommender: Epoch 146 of 200. Elapsed time 1.66 min
# Processed 69878 (100.0%) in 0.67 sec. BPR loss is 1.06E-01. Sample per second: 104418
# SLIM_BPR_Recommender: Epoch 147 of 200. Elapsed time 1.67 min
# Processed 69878 (100.0%) in 1.28 sec. BPR loss is 1.07E-01. Sample per second: 54542
# SLIM_BPR_Recommender: Epoch 148 of 200. Elapsed time 1.68 min
# Processed 69878 (100.0%) in 0.87 sec. BPR loss is 1.07E-01. Sample per second: 80495
# SLIM_BPR_Recommender: Epoch 149 of 200. Elapsed time 1.69 min
# Processed 69878 (100.0%) in 1.58 sec. BPR loss is 1.10E-01. Sample per second: 44141
# SLIM_BPR_Recommender: Epoch 150 of 200. Elapsed time 1.70 min
# Processed 69878 (100.0%) in 1.38 sec. BPR loss is 1.10E-01. Sample per second: 50551
# SLIM_BPR_Recommender: Epoch 151 of 200. Elapsed time 1.71 min
# Processed 69878 (100.0%) in 1.40 sec. BPR loss is 1.10E-01. Sample per second: 49868
# SLIM_BPR_Recommender: Epoch 152 of 200. Elapsed time 1.73 min
# Processed 69878 (100.0%) in 1.22 sec. BPR loss is 1.10E-01. Sample per second: 57088
# SLIM_BPR_Recommender: Epoch 153 of 200. Elapsed time 1.74 min
# Processed 69878 (100.0%) in 0.87 sec. BPR loss is 1.12E-01. Sample per second: 80326
# SLIM_BPR_Recommender: Epoch 154 of 200. Elapsed time 1.75 min
# Processed 69878 (100.0%) in 1.77 sec. BPR loss is 1.13E-01. Sample per second: 39483
# SLIM_BPR_Recommender: Epoch 155 of 200. Elapsed time 1.77 min
# Processed 69878 (100.0%) in 1.40 sec. BPR loss is 1.13E-01. Sample per second: 49833
# SLIM_BPR_Recommender: Epoch 156 of 200. Elapsed time 1.78 min
# Processed 69878 (100.0%) in 0.98 sec. BPR loss is 1.14E-01. Sample per second: 70928
# SLIM_BPR_Recommender: Epoch 157 of 200. Elapsed time 1.79 min
# Processed 69878 (100.0%) in 1.63 sec. BPR loss is 1.16E-01. Sample per second: 42867
# SLIM_BPR_Recommender: Epoch 158 of 200. Elapsed time 1.80 min
# Processed 69878 (100.0%) in 1.55 sec. BPR loss is 1.16E-01. Sample per second: 45133
# SLIM_BPR_Recommender: Epoch 159 of 200. Elapsed time 1.81 min
# Processed 69878 (100.0%) in 1.19 sec. BPR loss is 1.16E-01. Sample per second: 58614
# SLIM_BPR_Recommender: Epoch 160 of 200. Elapsed time 1.82 min
# Processed 69878 (100.0%) in 0.84 sec. BPR loss is 1.17E-01. Sample per second: 82888
# SLIM_BPR_Recommender: Epoch 161 of 200. Elapsed time 1.84 min
# Processed 69878 (100.0%) in 1.60 sec. BPR loss is 1.17E-01. Sample per second: 43543
# SLIM_BPR_Recommender: Epoch 162 of 200. Elapsed time 1.85 min
# Processed 69878 (100.0%) in 1.38 sec. BPR loss is 1.17E-01. Sample per second: 50742
# SLIM_BPR_Recommender: Epoch 163 of 200. Elapsed time 1.86 min
# Processed 69878 (100.0%) in 0.97 sec. BPR loss is 1.19E-01. Sample per second: 71663
# SLIM_BPR_Recommender: Epoch 164 of 200. Elapsed time 1.87 min
# Processed 69878 (100.0%) in 1.61 sec. BPR loss is 1.20E-01. Sample per second: 43321
# SLIM_BPR_Recommender: Epoch 165 of 200. Elapsed time 1.88 min
# Processed 69878 (100.0%) in 1.18 sec. BPR loss is 1.21E-01. Sample per second: 59066
# SLIM_BPR_Recommender: Epoch 166 of 200. Elapsed time 1.89 min
# Processed 69878 (100.0%) in 0.85 sec. BPR loss is 1.20E-01. Sample per second: 81664
# SLIM_BPR_Recommender: Epoch 167 of 200. Elapsed time 1.90 min
# Processed 69878 (100.0%) in 1.63 sec. BPR loss is 1.21E-01. Sample per second: 42844
# SLIM_BPR_Recommender: Epoch 168 of 200. Elapsed time 1.92 min
# Processed 69878 (100.0%) in 1.36 sec. BPR loss is 1.21E-01. Sample per second: 51481
# SLIM_BPR_Recommender: Epoch 169 of 200. Elapsed time 1.93 min
# Processed 69878 (100.0%) in 1.10 sec. BPR loss is 1.23E-01. Sample per second: 63743
# SLIM_BPR_Recommender: Epoch 170 of 200. Elapsed time 1.94 min
# Processed 69878 (100.0%) in 0.78 sec. BPR loss is 1.24E-01. Sample per second: 89913
# SLIM_BPR_Recommender: Epoch 171 of 200. Elapsed time 1.95 min
# Processed 69878 (100.0%) in 1.44 sec. BPR loss is 1.23E-01. Sample per second: 48455
# SLIM_BPR_Recommender: Epoch 172 of 200. Elapsed time 1.96 min
# Processed 69878 (100.0%) in 1.14 sec. BPR loss is 1.23E-01. Sample per second: 61352
# SLIM_BPR_Recommender: Epoch 173 of 200. Elapsed time 1.97 min
# Processed 69878 (100.0%) in 0.82 sec. BPR loss is 1.25E-01. Sample per second: 84708
# SLIM_BPR_Recommender: Epoch 174 of 200. Elapsed time 1.98 min
# Processed 69878 (100.0%) in 1.52 sec. BPR loss is 1.25E-01. Sample per second: 45983
# SLIM_BPR_Recommender: Epoch 175 of 200. Elapsed time 2.00 min
# Processed 69878 (100.0%) in 1.22 sec. BPR loss is 1.26E-01. Sample per second: 57266
# SLIM_BPR_Recommender: Epoch 176 of 200. Elapsed time 2.01 min
# Processed 69878 (100.0%) in 0.86 sec. BPR loss is 1.26E-01. Sample per second: 81381
# SLIM_BPR_Recommender: Epoch 177 of 200. Elapsed time 2.02 min
# Processed 69878 (100.0%) in 1.47 sec. BPR loss is 1.28E-01. Sample per second: 47589
# SLIM_BPR_Recommender: Epoch 178 of 200. Elapsed time 2.03 min
# Processed 69878 (100.0%) in 1.19 sec. BPR loss is 1.27E-01. Sample per second: 58806
# SLIM_BPR_Recommender: Epoch 179 of 200. Elapsed time 2.04 min
# Processed 69878 (100.0%) in 0.81 sec. BPR loss is 1.30E-01. Sample per second: 86250
# SLIM_BPR_Recommender: Epoch 180 of 200. Elapsed time 2.05 min
# Processed 69878 (100.0%) in 1.56 sec. BPR loss is 1.31E-01. Sample per second: 44871
# SLIM_BPR_Recommender: Epoch 181 of 200. Elapsed time 2.06 min
# Processed 69878 (100.0%) in 1.29 sec. BPR loss is 1.32E-01. Sample per second: 54075
# SLIM_BPR_Recommender: Epoch 182 of 200. Elapsed time 2.08 min
# Processed 69878 (100.0%) in 0.89 sec. BPR loss is 1.31E-01. Sample per second: 78411
# SLIM_BPR_Recommender: Epoch 183 of 200. Elapsed time 2.09 min
# Processed 69878 (100.0%) in 1.59 sec. BPR loss is 1.34E-01. Sample per second: 43809
# SLIM_BPR_Recommender: Epoch 184 of 200. Elapsed time 2.10 min
# Processed 69878 (100.0%) in 1.36 sec. BPR loss is 1.32E-01. Sample per second: 51270
# SLIM_BPR_Recommender: Epoch 185 of 200. Elapsed time 2.11 min
# Processed 69878 (100.0%) in 0.96 sec. BPR loss is 1.31E-01. Sample per second: 72344
# SLIM_BPR_Recommender: Epoch 186 of 200. Elapsed time 2.12 min
# Processed 69878 (100.0%) in 1.66 sec. BPR loss is 1.34E-01. Sample per second: 42173
# SLIM_BPR_Recommender: Epoch 187 of 200. Elapsed time 2.13 min
# Processed 69878 (100.0%) in 1.49 sec. BPR loss is 1.34E-01. Sample per second: 46768
# SLIM_BPR_Recommender: Epoch 188 of 200. Elapsed time 2.15 min
# Processed 69878 (100.0%) in 1.22 sec. BPR loss is 1.35E-01. Sample per second: 56952
# SLIM_BPR_Recommender: Epoch 189 of 200. Elapsed time 2.16 min
# Processed 69878 (100.0%) in 0.88 sec. BPR loss is 1.35E-01. Sample per second: 79640
# SLIM_BPR_Recommender: Epoch 190 of 200. Elapsed time 2.17 min
# Processed 69878 (100.0%) in 1.68 sec. BPR loss is 1.37E-01. Sample per second: 41538
# SLIM_BPR_Recommender: Epoch 191 of 200. Elapsed time 2.18 min
# Processed 69878 (100.0%) in 1.39 sec. BPR loss is 1.34E-01. Sample per second: 50304
# SLIM_BPR_Recommender: Epoch 192 of 200. Elapsed time 2.19 min
# Processed 69878 (100.0%) in 1.02 sec. BPR loss is 1.37E-01. Sample per second: 68438
# SLIM_BPR_Recommender: Epoch 193 of 200. Elapsed time 2.20 min
# Processed 69878 (100.0%) in 0.70 sec. BPR loss is 1.37E-01. Sample per second: 99411
# SLIM_BPR_Recommender: Epoch 194 of 200. Elapsed time 2.22 min
# Processed 69878 (100.0%) in 1.42 sec. BPR loss is 1.41E-01. Sample per second: 49042
# SLIM_BPR_Recommender: Epoch 195 of 200. Elapsed time 2.23 min
# Processed 69878 (100.0%) in 1.12 sec. BPR loss is 1.41E-01. Sample per second: 62544
# SLIM_BPR_Recommender: Epoch 196 of 200. Elapsed time 2.24 min
# Processed 69878 (100.0%) in 0.90 sec. BPR loss is 1.41E-01. Sample per second: 77986
# SLIM_BPR_Recommender: Epoch 197 of 200. Elapsed time 2.25 min
# Processed 69878 (100.0%) in 1.69 sec. BPR loss is 1.42E-01. Sample per second: 41259
# SLIM_BPR_Recommender: Epoch 198 of 200. Elapsed time 2.27 min
# Processed 69878 (100.0%) in 1.46 sec. BPR loss is 1.41E-01. Sample per second: 47700
# SLIM_BPR_Recommender: Epoch 199 of 200. Elapsed time 2.28 min
# Processed 69878 (100.0%) in 1.22 sec. BPR loss is 1.44E-01. Sample per second: 57280
# SLIM_BPR_Recommender: Epoch 200 of 200. Elapsed time 2.29 min
# SLIM_BPR_Recommender: Terminating at epoch 200. Elapsed time 2.37 min
# Deallocating Cython objects

# %% [markdown]
# Both of these recommenders have the `_compute_item_score` function. However, the scores might be totally different.
#
# Let's see

# %%
funk_svd_score = funk_svd_recommender._compute_item_score(user_id)
funk_svd_score
# Out:
# array([3.38101759, 3.37078132, 2.92108968, ..., 3.59797302, 3.4846974 ,
#        3.53364231])

# %%
slim_bpr_score = slim_bpr_recommender._compute_item_score(user_id).flatten()
slim_bpr_score
# Out:
# array([0.02890435, 1.2552136 , 1.3844359 , ..., 0.        , 0.        ,
#        0.        ], dtype=float32)

# %% [markdown]
# Here is where things get complicated. You see, the scores that each function computes have completely different meanings, we cannot just join them as if they are the same thing.
#
# Let's calculate some percentiles and do some visualizations on the scores.

# %%
import seaborn as sns
import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt

# %%
_ = plt.figure(figsize=(16,7))
ax = sns.scatterplot(data=funk_svd_score)

# %%
np.percentile(funk_svd_score, [0, 25, 50, 75, 100])
# Out:
# array([2.71507139, 3.493482  , 3.51879631, 3.54436485, 4.4754792 ])

# %%
_ = plt.figure(figsize=(16,7))
ax = sns.boxplot(x=funk_svd_score)

# %%
_ = plt.figure(figsize=(16,7))
ax = sns.scatterplot(data=slim_bpr_score)

# %%
np.percentile(slim_bpr_score, [0, 25, 50, 75, 100])
# Out:
# array([0.        , 0.        , 0.        , 0.        , 1.77471876])

# %%
_ = plt.figure(figsize=(16,7))
ax = sns.boxplot(x=slim_bpr_score)

# %% [markdown]
# As you can see from the plots and the percentiles, the values held in each score array is totally different from one to another.
#
# As such, we need a way to _normalize_ these scores to be able to merge them into one.

# %%
l1_funk_svd = LA.norm([funk_svd_score], 1)
l1_funk_svd_scores = funk_svd_score / l1_funk_svd

l2_funk_svd = LA.norm([funk_svd_score], 2)
l2_funk_svd_scores = funk_svd_score / l2_funk_svd

linf_funk_svd = LA.norm(funk_svd_score, np.inf)
linf_funk_svd_scores = funk_svd_score / linf_funk_svd

lminusinf_funk_svd = LA.norm(funk_svd_score, -np.inf)
lminusinf_funk_svd_scores = funk_svd_score / lminusinf_funk_svd

print(funk_svd_score, l1_funk_svd, l2_funk_svd, linf_funk_svd, lminusinf_funk_svd)

_ = plt.figure(figsize=(16,7))
ax = sns.scatterplot(data=funk_svd_score)
ax = sns.scatterplot(data=l1_funk_svd_scores) 
ax = sns.scatterplot(data=l2_funk_svd_scores) 
ax = sns.scatterplot(data=linf_funk_svd_scores) 
ax = sns.scatterplot(data=lminusinf_funk_svd_scores) 
ax.legend(["Funk SVD Score", "L1 Scores", "L2 Scores", "LInf Scores", "LMinusInf Scores"])
# Out:
# [3.38101759 3.37078132 2.92108968 ... 3.59797302 3.4846974  3.53364231] 4.475479200696971 364.0088754371894 4.475479200696971 2.715071392321457

# %% [markdown]
# Similarly, we can do the same with SLIM BPR scores

# %%
l1_slim_bpr = LA.norm(slim_bpr_score, 1)
l1_slim_bpr_scores = slim_bpr_score / l1_slim_bpr

l2_slim_bpr = LA.norm(slim_bpr_score, 2)
l2_slim_bpr_scores = slim_bpr_score / l2_slim_bpr

linf_slim_bpr = LA.norm(slim_bpr_score, np.inf)
linf_slim_bpr_scores = slim_bpr_score / linf_slim_bpr

lminusinf_slim_bpr = LA.norm(slim_bpr_score, -np.inf)
lminusinf_slim_bpr_scores = slim_bpr_score / lminusinf_slim_bpr

print(slim_bpr_score, l1_slim_bpr, l2_slim_bpr, linf_slim_bpr, lminusinf_slim_bpr)

_ = plt.figure(figsize=(16,9))
ax = sns.scatterplot(data=slim_bpr_score)
ax = sns.scatterplot(data=l1_slim_bpr_scores) 
ax = sns.scatterplot(data=l2_slim_bpr_scores) 
ax = sns.scatterplot(data=linf_slim_bpr_scores) 
ax = sns.scatterplot(data=lminusinf_slim_bpr_scores) 
ax.legend(["SLIM BPR Score", "L1 Scores", "L2 Scores", "LInf Scores", "LMinusInf Scores"])
# Out:
# [0.02890435 1.2552136  1.3844359  ... 0.         0.         0.        ] 126.3779 10.485089 1.7747188 0.0
# <ipython-input-34-ed214cbf1a39>:11: RuntimeWarning: divide by zero encountered in true_divide
#   lminusinf_slim_bpr_scores = slim_bpr_score / lminusinf_slim_bpr
# <ipython-input-34-ed214cbf1a39>:11: RuntimeWarning: invalid value encountered in true_divide
#   lminusinf_slim_bpr_scores = slim_bpr_score / lminusinf_slim_bpr

# %% [markdown]
# Now that we have *normalized* the different item score vectors, we can merge the models.

# %%
lambda_weights = 0.66

l1_new_scores = lambda_weights * l1_slim_bpr_scores + (1 - lambda_weights) * l1_funk_svd_scores
l2_new_scores = lambda_weights * l2_slim_bpr_scores + (1 - lambda_weights) * l2_funk_svd_scores
linf_new_scores = lambda_weights * linf_slim_bpr_scores + (1 - lambda_weights) * linf_funk_svd_scores
lminusinf_new_scores = lambda_weights * lminusinf_slim_bpr_scores + (1 - lambda_weights) * lminusinf_funk_svd_scores

_ = plt.figure(figsize=(16,9))
ax = sns.scatterplot(data=l1_new_scores)
ax = sns.scatterplot(data=l2_new_scores) 
ax = sns.scatterplot(data=linf_new_scores) 
ax = sns.scatterplot(data=lminusinf_new_scores) 
ax.legend(["L1 Scores", "L2 Scores", "LInf Scores", "LMinusInf Scores"])

# %% [markdown]
# Now, we have everything to create our hybrid.

# %%
class DifferentLossScoresHybridRecommender(BaseRecommender):
    """ ScoresHybridRecommender
    Hybrid of two prediction scores R = R1/norm*alpha + R2/norm*(1-alpha) where R1 and R2 come from
    algorithms trained on different loss functions.

    """

    RECOMMENDER_NAME = "DifferentLossScoresHybridRecommender"


    def __init__(self, URM_train, recommender_1, recommender_2):
        super(DifferentLossScoresHybridRecommender, self).__init__(URM_train)

        self.URM_train = sps.csr_matrix(URM_train)
        self.recommender_1 = recommender_1
        self.recommender_2 = recommender_2
        
        
        
    def fit(self, norm, alpha = 0.5):

        self.alpha = alpha
        self.norm = norm


    def _compute_item_score(self, user_id_array, items_to_compute):
        
        item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
        item_weights_2 = self.recommender_2._compute_item_score(user_id_array)

        norm_item_weights_1 = LA.norm(item_weights_1, self.norm)
        norm_item_weights_2 = LA.norm(item_weights_2, self.norm)
        
        
        if norm_item_weights_1 == 0:
            raise ValueError("Norm {} of item weights for recommender 1 is zero. Avoiding division by zero".format(self.norm))
        
        if norm_item_weights_2 == 0:
            raise ValueError("Norm {} of item weights for recommender 2 is zero. Avoiding division by zero".format(self.norm))
        
        item_weights = item_weights_1 / norm_item_weights_1 * self.alpha + item_weights_2 / norm_item_weights_2 * (1-self.alpha)

        return item_weights

# %%
recommender_object = DifferentLossScoresHybridRecommender(URM_train, funk_svd_recommender, slim_bpr_recommender)

for norm in [1, 2, np.inf, -np.inf]:

    recommender_object.fit(norm, alpha = 0.66)

    result_df, _ = evaluator_validation.evaluateRecommender(recommender_object)
    print("Norm: {}, Result: {}".format(norm, result_df.loc[10]["MAP"]))
# Out:
# DifferentLossScoresHybridRecommender: URM Detected 56 ( 0.5%) items with no interactions.
# EvaluatorHoldout: Processed 69646 (100.0%) in 2.85 min. Users per second: 408
# Norm: 1, Result: 0.07825201278666545
# EvaluatorHoldout: Processed 17000 (24.4%) in 5.02 min. Users per second: 56
# EvaluatorHoldout: Processed 35000 (50.3%) in 10.04 min. Users per second: 58
# EvaluatorHoldout: Processed 53000 (76.1%) in 15.10 min. Users per second: 58
# EvaluatorHoldout: Processed 69646 (100.0%) in 19.73 min. Users per second: 59
# Norm: 2, Result: 0.08802796876631806
# EvaluatorHoldout: Processed 69646 (100.0%) in 2.79 min. Users per second: 416
# Norm: inf, Result: 0.08816857780550014
# EvaluatorHoldout: Processed 69646 (100.0%) in 2.85 min. Users per second: 408
# Norm: -inf, Result: 0.08880076010245849

# %% [markdown]
# ## Important note:
#
# You can build a hybrid with any number of techniques and models, be advised however that optimizing them is difficult.
# * If you use already trained and optimized models and try to combine them you have a weight per each model and possibly a normalization. If you put together 10 models it will be difficult for the optimizer to find good hyperparameters due to a number of problems, for example the noise introduced by the lower performing algorithms;
# * If you decide to try to optimize both the hybrid hyperparameters and each single model hyperparameters all at once, you end up with hundreds of hyperparameters to optimize. In theory you could be able to find a better result, in practice you will likely not.
# * Some strategies can be used to minimize this, for example some smart initial points you provide to the optimizer... Maybe you start from all the hyperparameter configurations of the single models taken independently that you have already optimized, you use them as initialization points for the optimizer and then you try to *further* optimize them as part of the hybrid. (may be complicated, result is not guaranteed)
#
# A good solution is to proceed incrementally. For example:
# * Start with the best model and set a weight and normalization, let's say 1.0 and l1;
# * Add the second-best model and try to create a hybrid of the two optimizing only weight and normalization of the model you are trying to add;
# * Once the optimization concludes, check if the hybrid is better than before or not. If it is better keep the new hybrid, if not remove the second-best model.
# * Continue trying to add the third-best, fourth-best and so on...
# * If you are lucky every now and then a new model can be added and the quality improves. (again, result not guaranteed)
#
#
# Alternatively you can combine the model predictions with more complex strategies, for example with XGBoost. This is usually the go-to approach for hybrids that we use in the international challenges but goes beyond the scope of this course.

# %% [markdown]
# # Some tricks, user-wise hybrids
#
# Models do not have the same accuracy for different user types. Let's divide the users according to their profile length and then compare the recommendation quality we get from a CF model.
#
# Let's categorize user based on the number of interactions they have.

# %%
import numpy as np 
import scipy.sparse as sps

profile_length = np.ediff1d(sps.csr_matrix(URM_train).indptr)
profile_length, profile_length.shape
# Out:
# (array([15, 13, 20, ..., 94, 30, 38], dtype=int32), (69878,))

# %% [markdown]
# Let's select a few groups of 5% of the users with the least number of interactions.

# %%
block_size = int(len(profile_length)*0.05)
block_size
# Out:
# 3493

# %%
sorted_users = np.argsort(profile_length)
sorted_users
# Out:
# array([32755, 21863,  7680, ..., 14085, 65888, 57959], dtype=int64)

# %%
for group_id in range(0, 20):
    start_pos = group_id * block_size
    end_pos = min((group_id+1) * block_size, len(profile_length))
    
    users_in_group = sorted_users[start_pos:end_pos]
    
    users_in_group_p_len = profile_length[users_in_group]
    
    print("Group {}, #users in group {}, average p.len {:.2f}, median {}, min {}, max {}".format(
        group_id, 
        users_in_group.shape[0],
        users_in_group_p_len.mean(),
        np.median(users_in_group_p_len),
        users_in_group_p_len.min(),
        users_in_group_p_len.max()))
# Out:
# Group 0, #users in group 3493, average p.len 11.76, median 12.0, min 5, max 13
# Group 1, #users in group 3493, average p.len 14.58, median 15.0, min 13, max 16
# Group 2, #users in group 3493, average p.len 16.62, median 17.0, min 16, max 18
# Group 3, #users in group 3493, average p.len 18.84, median 19.0, min 18, max 20
# Group 4, #users in group 3493, average p.len 21.30, median 21.0, min 20, max 23
# Group 5, #users in group 3493, average p.len 24.20, median 24.0, min 23, max 26
# Group 6, #users in group 3493, average p.len 27.56, median 28.0, min 26, max 29
# Group 7, #users in group 3493, average p.len 31.48, median 31.0, min 29, max 34
# Group 8, #users in group 3493, average p.len 35.97, median 36.0, min 34, max 38
# Group 9, #users in group 3493, average p.len 41.34, median 41.0, min 38, max 44
# Group 10, #users in group 3493, average p.len 47.76, median 48.0, min 44, max 51
# Group 11, #users in group 3493, average p.len 55.59, median 55.0, min 51, max 60
# Group 12, #users in group 3493, average p.len 64.91, median 65.0, min 60, max 70
# Group 13, #users in group 3493, average p.len 75.76, median 76.0, min 70, max 83
# Group 14, #users in group 3493, average p.len 90.87, median 91.0, min 83, max 100
# Group 15, #users in group 3493, average p.len 111.47, median 111.0, min 100, max 124
# Group 16, #users in group 3493, average p.len 140.42, median 140.0, min 124, max 159
# Group 17, #users in group 3493, average p.len 184.11, median 183.0, min 159, max 215
# Group 18, #users in group 3493, average p.len 262.66, median 258.0, min 215, max 328
# Group 19, #users in group 3493, average p.len 541.78, median 463.0, min 328, max 1810

# %% [markdown]
# Now let's calculate the evaluation metrics of each recommender when considering groups of users.

# %%
from Recommenders.NonPersonalizedRecommender import TopPop
from Recommenders.KNN.UserKNNCFRecommender import UserKNNCFRecommender
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython
from Recommenders.SLIM.SLIMElasticNetRecommender import SLIMElasticNetRecommender
from Recommenders.GraphBased.P3alphaRecommender import P3alphaRecommender
from Recommenders.GraphBased.RP3betaRecommender import RP3betaRecommender
from Recommenders.MatrixFactorization.Cython.MatrixFactorization_Cython import MatrixFactorization_BPR_Cython, MatrixFactorization_FunkSVD_Cython, MatrixFactorization_AsySVD_Cython
from Recommenders.MatrixFactorization.PureSVDRecommender import PureSVDRecommender
from Recommenders.MatrixFactorization.IALSRecommender import IALSRecommender
from Recommenders.MatrixFactorization.NMFRecommender import NMFRecommender

MAP_recommender_per_group = {}

collaborative_recommender_class = {"TopPop": TopPop,
                                   "UserKNNCF": UserKNNCFRecommender,
                                   "ItemKNNCF": ItemKNNCFRecommender,
                                   "P3alpha": P3alphaRecommender,
                                   "RP3beta": RP3betaRecommender,
                                   "PureSVD": PureSVDRecommender,
                                   "NMF": NMFRecommender,
                                   "FunkSVD": MatrixFactorization_FunkSVD_Cython,
                                   "SLIMBPR": SLIM_BPR_Cython,
                                   }

content_recommender_class = {"ItemKNNCBF": ItemKNNCBFRecommender,
                             "ItemKNNCFCBF": ItemKNN_CFCBF_Hybrid_Recommender
                            }

recommender_object_dict = {}

for label, recommender_class in collaborative_recommender_class.items():
    recommender_object = recommender_class(URM_train)
    recommender_object.fit()
    recommender_object_dict[label] = recommender_object

for label, recommender_class in content_recommender_class.items():
    recommender_object = recommender_class(URM_train, ICM_genres)
    recommender_object.fit()
    recommender_object_dict[label] = recommender_object
# Out:
# TopPopRecommender: URM Detected 56 ( 0.5%) items with no interactions.
# UserKNNCFRecommender: URM Detected 56 ( 0.5%) items with no interactions.
# Similarity column 67565 (96.7%), 225.18 column/sec. Elapsed time 5.00 min
# Similarity column 69878 (100.0%), 225.04 column/sec. Elapsed time 5.18 min
# ItemKNNCFRecommender: URM Detected 56 ( 0.5%) items with no interactions.
# Similarity column 10681 (100.0%), 869.02 column/sec. Elapsed time 12.29 sec
# P3alphaRecommender: URM Detected 56 ( 0.5%) items with no interactions.
# RP3betaRecommender: URM Detected 56 ( 0.5%) items with no interactions.
# PureSVDRecommender: URM Detected 56 ( 0.5%) items with no interactions.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... done in 5.46 sec
# NMFRecommender: URM Detected 56 ( 0.5%) items with no interactions.
# NMFRecommender: Computing NMF decomposition...
# NMFRecommender: Computing NMF decomposition... done in 5.40 min
# MatrixFactorization_FunkSVD_Cython_Recommender: URM Detected 56 ( 0.5%) items with no interactions.
# FUNK_SVD: Processed 6401000 (100.0%) in 8.15 sec. MSE loss 2.16E+00. Sample per second: 785245
# FUNK_SVD: Epoch 1 of 300. Elapsed time 7.63 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 8.78 sec. MSE loss 1.13E+00. Sample per second: 728985
# FUNK_SVD: Epoch 2 of 300. Elapsed time 16.26 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 8.95 sec. MSE loss 1.13E+00. Sample per second: 714883
# FUNK_SVD: Epoch 3 of 300. Elapsed time 24.43 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 9.29 sec. MSE loss 1.13E+00. Sample per second: 689031
# FUNK_SVD: Epoch 4 of 300. Elapsed time 32.77 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 8.46 sec. MSE loss 1.12E+00. Sample per second: 756611
# FUNK_SVD: Epoch 5 of 300. Elapsed time 40.94 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 7.87 sec. MSE loss 1.12E+00. Sample per second: 813702
# FUNK_SVD: Epoch 6 of 300. Elapsed time 48.34 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 8.66 sec. MSE loss 1.12E+00. Sample per second: 739336
# FUNK_SVD: Epoch 7 of 300. Elapsed time 56.14 sec
# FUNK_SVD: Processed 6401000 (100.0%) in 9.07 sec. MSE loss 1.12E+00. Sample per second: 705683
# FUNK_SVD: Epoch 8 of 300. Elapsed time 1.08 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.59 sec. MSE loss 1.11E+00. Sample per second: 745561
# FUNK_SVD: Epoch 9 of 300. Elapsed time 1.22 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.63 sec. MSE loss 1.11E+00. Sample per second: 741347
# FUNK_SVD: Epoch 10 of 300. Elapsed time 1.35 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.50 sec. MSE loss 1.11E+00. Sample per second: 753414
# FUNK_SVD: Epoch 11 of 300. Elapsed time 1.48 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.15 sec. MSE loss 1.11E+00. Sample per second: 785528
# FUNK_SVD: Epoch 12 of 300. Elapsed time 1.61 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.59 sec. MSE loss 1.11E+00. Sample per second: 745048
# FUNK_SVD: Epoch 13 of 300. Elapsed time 1.75 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.92 sec. MSE loss 1.10E+00. Sample per second: 717490
# FUNK_SVD: Epoch 14 of 300. Elapsed time 1.89 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.01 sec. MSE loss 1.10E+00. Sample per second: 798666
# FUNK_SVD: Epoch 15 of 300. Elapsed time 2.01 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.82 sec. MSE loss 1.10E+00. Sample per second: 818571
# FUNK_SVD: Epoch 16 of 300. Elapsed time 2.14 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.82 sec. MSE loss 1.10E+00. Sample per second: 725123
# FUNK_SVD: Epoch 17 of 300. Elapsed time 2.27 min
# FUNK_SVD: Processed 6401000 (100.0%) in 9.20 sec. MSE loss 1.10E+00. Sample per second: 695872
# FUNK_SVD: Epoch 18 of 300. Elapsed time 2.41 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.83 sec. MSE loss 1.09E+00. Sample per second: 816963
# FUNK_SVD: Epoch 19 of 300. Elapsed time 2.54 min
# FUNK_SVD: Processed 6401000 (100.0%) in 9.06 sec. MSE loss 1.09E+00. Sample per second: 706356
# FUNK_SVD: Epoch 20 of 300. Elapsed time 2.68 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.20 sec. MSE loss 1.09E+00. Sample per second: 781020
# FUNK_SVD: Epoch 21 of 300. Elapsed time 2.81 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.59 sec. MSE loss 1.09E+00. Sample per second: 744749
# FUNK_SVD: Epoch 22 of 300. Elapsed time 2.95 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7
97 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.29 sec. MSE loss 9.98E-01. Sample per second: 771998
# FUNK_SVD: Epoch 202 of 300. Elapsed time 26.10 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.30 sec. MSE loss 9.97E-01. Sample per second: 876571
# FUNK_SVD: Epoch 203 of 300. Elapsed time 26.21 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.08 sec. MSE loss 9.99E-01. Sample per second: 792389
# FUNK_SVD: Epoch 204 of 300. Elapsed time 26.34 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.01 sec. MSE loss 9.98E-01. Sample per second: 799491
# FUNK_SVD: Epoch 205 of 300. Elapsed time 26.47 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.02 sec. MSE loss 9.97E-01. Sample per second: 911286
# FUNK_SVD: Epoch 206 of 300. Elapsed time 26.59 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.30 sec. MSE loss 9.96E-01. Sample per second: 770751
# FUNK_SVD: Epoch 207 of 300. Elapsed time 26.73 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.98 sec. MSE loss 9.97E-01. Sample per second: 801595
# FUNK_SVD: Epoch 208 of 300. Elapsed time 26.86 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.51 sec. MSE loss 9.97E-01. Sample per second: 752465
# FUNK_SVD: Epoch 209 of 300. Elapsed time 26.98 min
# FUNK_SVD: Processed 6401000 (100.0%) in 9.24 sec. MSE loss 9.96E-01. Sample per second: 692914
# FUNK_SVD: Epoch 210 of 300. Elapsed time 27.13 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.22 sec. MSE loss 9.96E-01. Sample per second: 778881
# FUNK_SVD: Epoch 211 of 300. Elapsed time 27.26 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.49 sec. MSE loss 9.97E-01. Sample per second: 753634
# FUNK_SVD: Epoch 212 of 300. Elapsed time 27.40 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.52 sec. MSE loss 9.96E-01. Sample per second: 751627
# FUNK_SVD: Epoch 213 of 300. Elapsed time 27.53 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.94 sec. MSE loss 9.95E-01. Sample per second: 806301
# FUNK_SVD: Epoch 214 of 300. Elapsed time 27.66 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.61 sec. MSE loss 9.96E-01. Sample per second: 743252
# FUNK_SVD: Epoch 215 of 300. Elapsed time 27.78 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.80 sec. MSE loss 9.95E-01. Sample per second: 820209
# FUNK_SVD: Epoch 216 of 300. Elapsed time 27.90 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.19 sec. MSE loss 9.94E-01. Sample per second: 781163
# FUNK_SVD: Epoch 217 of 300. Elapsed time 28.03 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.80 sec. MSE loss 9.95E-01. Sample per second: 820291
# FUNK_SVD: Epoch 218 of 300. Elapsed time 28.15 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.93 sec. MSE loss 9.95E-01. Sample per second: 807191
# FUNK_SVD: Epoch 219 of 300. Elapsed time 28.27 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.71 sec. MSE loss 9.94E-01. Sample per second: 735225
# FUNK_SVD: Epoch 220 of 300. Elapsed time 28.40 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.33 sec. MSE loss 9.94E-01. Sample per second: 768582
# FUNK_SVD: Epoch 221 of 300. Elapsed time 28.53 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.35 sec. MSE loss 9.94E-01. Sample per second: 766286
# FUNK_SVD: Epoch 222 of 300. Elapsed time 28.66 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.35 sec. MSE loss 9.93E-01. Sample per second: 767006
# FUNK_SVD: Epoch 223 of 300. Elapsed time 28.80 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.31 sec. MSE loss 9.93E-01. Sample per second: 769884
# FUNK_SVD: Epoch 224 of 300. Elapsed time 28.93 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.14 sec. MSE loss 9.94E-01. Sample per second: 786127
# FUNK_SVD: Epoch 225 of 300. Elapsed time 29.06 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.62 sec. MSE loss 9.93E-01. Sample per second: 742803
# FUNK_SVD: Epoch 226 of 300. Elapsed time 29.20 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7
min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.73 sec. MSE loss 9.88E-01. Sample per second: 732925
# FUNK_SVD: Epoch 253 of 300. Elapsed time 32.74 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.70 sec. MSE loss 9.88E-01. Sample per second: 735463
# FUNK_SVD: Epoch 254 of 300. Elapsed time 32.87 min
# FUNK_SVD: Processed 6401000 (100.0%) in 9.27 sec. MSE loss 9.87E-01. Sample per second: 690723
# FUNK_SVD: Epoch 255 of 300. Elapsed time 33.01 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.97 sec. MSE loss 9.88E-01. Sample per second: 803221
# FUNK_SVD: Epoch 256 of 300. Elapsed time 33.14 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.64 sec. MSE loss 9.87E-01. Sample per second: 741049
# FUNK_SVD: Epoch 257 of 300. Elapsed time 33.27 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.02 sec. MSE loss 9.88E-01. Sample per second: 798577
# FUNK_SVD: Epoch 258 of 300. Elapsed time 33.39 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.05 sec. MSE loss 9.88E-01. Sample per second: 794858
# FUNK_SVD: Epoch 259 of 300. Elapsed time 33.53 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.57 sec. MSE loss 9.87E-01. Sample per second: 844850
# FUNK_SVD: Epoch 260 of 300. Elapsed time 33.65 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.51 sec. MSE loss 9.88E-01. Sample per second: 751893
# FUNK_SVD: Epoch 261 of 300. Elapsed time 33.78 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.61 sec. MSE loss 9.86E-01. Sample per second: 743604
# FUNK_SVD: Epoch 262 of 300. Elapsed time 33.92 min
# FUNK_SVD: Processed 6401000 (100.0%) in 9.74 sec. MSE loss 9.87E-01. Sample per second: 657458
# FUNK_SVD: Epoch 263 of 300. Elapsed time 34.07 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.77 sec. MSE loss 9.86E-01. Sample per second: 730233
# FUNK_SVD: Epoch 264 of 300. Elapsed time 34.20 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.85 sec. MSE loss 9.86E-01. Sample per second: 723016
# FUNK_SVD: Epoch 265 of 300. Elapsed time 34.34 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.45 sec. MSE loss 9.86E-01. Sample per second: 757822
# FUNK_SVD: Epoch 266 of 300. Elapsed time 34.47 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.52 sec. MSE loss 9.86E-01. Sample per second: 750904
# FUNK_SVD: Epoch 267 of 300. Elapsed time 34.60 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.93 sec. MSE loss 9.85E-01. Sample per second: 806975
# FUNK_SVD: Epoch 268 of 300. Elapsed time 34.72 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.60 sec. MSE loss 9.86E-01. Sample per second: 744444
# FUNK_SVD: Epoch 269 of 300. Elapsed time 34.85 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.93 sec. MSE loss 9.86E-01. Sample per second: 807265
# FUNK_SVD: Epoch 270 of 300. Elapsed time 34.97 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.60 sec. MSE loss 9.85E-01. Sample per second: 744219
# FUNK_SVD: Epoch 271 of 300. Elapsed time 35.10 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.68 sec. MSE loss 9.84E-01. Sample per second: 737005
# FUNK_SVD: Epoch 272 of 300. Elapsed time 35.24 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.48 sec. MSE loss 9.85E-01. Sample per second: 754444
# FUNK_SVD: Epoch 273 of 300. Elapsed time 35.37 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.71 sec. MSE loss 9.84E-01. Sample per second: 734868
# FUNK_SVD: Epoch 274 of 300. Elapsed time 35.50 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.32 sec. MSE loss 9.83E-01. Sample per second: 769427
# FUNK_SVD: Epoch 275 of 300. Elapsed time 35.63 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.57 sec. MSE loss 9.83E-01. Sample per second: 844909
# FUNK_SVD: Epoch 276 of 300. Elapsed time 35.75 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.79 sec. MSE loss 9.83E-01. Sample per second: 728375
# FUNK_SVD: Epoch 277 of 300. Elapsed time 35.89 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.66 sec. MSE loss 9.84E-01. Sample per second: 835996
# FUNK_SVD: Epoch 278 of 300. Elapsed time 36.00 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.86 sec. MSE loss 9.84E-01. Sample per second: 722362
# FUNK_SVD: Epoch 279 of 300. Elapsed time 36.14 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.77 sec. MSE loss 9.83E-01. Sample per second: 730253
# FUNK_SVD: Epoch 280 of 300. Elapsed time 36.27 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.85 sec. MSE loss 9.82E-01. Sample per second: 722792
# FUNK_SVD: Epoch 281 of 300. Elapsed time 36.41 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.45 sec. MSE loss 9.84E-01. Sample per second: 756985
# FUNK_SVD: Epoch 282 of 300. Elapsed time 36.53 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.81 sec. MSE loss 9.84E-01. Sample per second: 819289
# FUNK_SVD: Epoch 283 of 300. Elapsed time 36.65 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.89 sec. MSE loss 9.83E-01. Sample per second: 811552
# FUNK_SVD: Epoch 284 of 300. Elapsed time 36.77 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.05 sec. MSE loss 9.83E-01. Sample per second: 794770
# FUNK_SVD: Epoch 285 of 300. Elapsed time 36.89 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.41 sec. MSE loss 9.82E-01. Sample per second: 863364
# FUNK_SVD: Epoch 286 of 300. Elapsed time 37.01 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.57 sec. MSE loss 9.82E-01. Sample per second: 746723
# FUNK_SVD: Epoch 287 of 300. Elapsed time 37.15 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.84 sec. MSE loss 9.82E-01. Sample per second: 723738
# FUNK_SVD: Epoch 288 of 300. Elapsed time 37.29 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.28 sec. MSE loss 9.82E-01. Sample per second: 773070
# FUNK_SVD: Epoch 289 of 300. Elapsed time 37.41 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.30 sec. MSE loss 9.81E-01. Sample per second: 770919
# FUNK_SVD: Epoch 290 of 300. Elapsed time 37.55 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.86 sec. MSE loss 9.82E-01. Sample per second: 814822
# FUNK_SVD: Epoch 291 of 300. Elapsed time 37.67 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.81 sec. MSE loss 9.81E-01. Sample per second: 726891
# FUNK_SVD: Epoch 292 of 300. Elapsed time 37.80 min
# FUNK_SVD: Processed 6401000 (100.0%) in 9.00 sec. MSE loss 9.80E-01. Sample per second: 711362
# FUNK_SVD: Epoch 293 of 300. Elapsed time 37.94 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.82 sec. MSE loss 9.81E-01. Sample per second: 818651
# FUNK_SVD: Epoch 294 of 300. Elapsed time 38.07 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.05 sec. MSE loss 9.81E-01. Sample per second: 795257
# FUNK_SVD: Epoch 295 of 300. Elapsed time 38.19 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.99 sec. MSE loss 9.80E-01. Sample per second: 800794
# FUNK_SVD: Epoch 296 of 300. Elapsed time 38.32 min
# FUNK_SVD: Processed 6401000 (100.0%) in 9.08 sec. MSE loss 9.81E-01. Sample per second: 705150
# FUNK_SVD: Epoch 297 of 300. Elapsed time 38.46 min
# FUNK_SVD: Processed 6401000 (100.0%) in 7.37 sec. MSE loss 9.81E-01. Sample per second: 868697
# FUNK_SVD: Epoch 298 of 300. Elapsed time 38.58 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.05 sec. MSE loss 9.80E-01. Sample per second: 794959
# FUNK_SVD: Epoch 299 of 300. Elapsed time 38.71 min
# FUNK_SVD: Processed 6401000 (100.0%) in 8.09 sec. MSE loss 9.80E-01. Sample per second: 791409
# FUNK_SVD: Epoch 300 of 300. Elapsed time 38.84 min
# FUNK_SVD: Terminating at epoch 300. Elapsed time 38.84 min
# SLIM_BPR_Recommender: URM Detected 56 ( 0.5%) items with no interactions.
# Unable to read memory status: list index out of range
# SLIM_BPR_Recommender: Automatic selection of fastest train mode. Unable to get current RAM status, you may be using a non-Linux operating system. Using dense matrix.
# Processed 69878 (100.0%) in 1.30 sec. BPR loss is 3.60E-04. Sample per second: 53826
# SLIM_BPR_Recommender: Epoch 1 of 300. Elapsed time 0.72 sec
# Processed 69878 (100.0%) in 1.01 sec. BPR loss is 1.14E-03. Sample per second: 69252
# SLIM_BPR_Recommender: Epoch 2 of 300. Elapsed time 1.43 sec
# Processed 69878 (100.0%) in 0.69 sec. BPR loss is 1.95E-03. Sample per second: 100552
# SLIM_BPR_Recommender: Epoch 3 of 300. Elapsed time 2.11 sec
# Processed 69878 (100.0%) in 1.49 sec. BPR loss is 2.76E-03. Sample per second: 46844
# SLIM_BPR_Recommender: Epoch 4 of 300. Elapsed time 2.91 sec
# Processed 69878 (100.0%) in 1.26 sec. BPR loss is 3.59E-03. Sample per second: 55412
# SLIM_BPR_Recommender: Epoch 5 of 300. Elapsed time 3.68 sec
# Processed 69878 (100.0%) in 0.92 sec. BPR loss is 4.34E-03. Sample per second: 76123
# SLIM_BPR_Recommender: Epoch 6 of 300. Elapsed time 4.34 sec
# Processed 69878 (100.0%) in 1.52 sec. BPR loss is 5.09E-03. Sample per second: 45946
# SLIM_BPR_Recommender: Epoch 7 of 300. Elapsed time 4.94 sec
# Processed 69878 (100.0%) in 1.12 sec. BPR loss is 6.00E-03. Sample per second: 62432
# SLIM_BPR_Recommender: Epoch 8 of 300. Elapsed time 5.54 sec
# Processed 69878 (100.0%) in 0.75 sec. BPR loss is 6.84E-03. Sample per second: 92530
# SLIM_BPR_Recommender: Epoch 9 of 300. Elapsed time 6.17 sec
# Processed 69878 (100.0%) in 1.53 sec. BPR loss is 7.52E-03. Sample per second: 45778
# SLIM_BPR_Recommender: Epoch 10 of 300. Elapsed time 6.95 sec
# Processed 69878 (100.0%) in 1.21 sec. BPR loss is 8.36E-03. Sample per second: 57663
# SLIM_BPR_Recommender: Epoch 11 of 300. Elapsed time 7.63 sec
# Processed 69878 (100.0%) in 0.83 sec. BPR loss is 9.11E-03. Sample per second: 83854
# SLIM_BPR_Recommender: Epoch 12 of 300. Elapsed time 8.25 sec
# Processed 69878 (100.0%) in 1.55 sec. BPR loss is 9.96E-03. Sample per second: 45021
# SLIM_BPR_Recommender: Epoch 13 of 300. Elapsed time 8.97 sec
# Processed 69878 (100.0%) in 1.47 sec. BPR loss is 1.07E-02. Sample per second: 47508
# SLIM_BPR_Recommender: Epoch 14 of 300. Elapsed time 9.89 sec
# Processed 69878 (100.0%) in 1.19 sec. BPR loss is 1.16E-02. Sample per second: 58682
# SLIM_BPR_Recommender: Epoch 15 of 300. Elapsed time 10.61 sec
# Processed 69878 (100.0%) in 0.91 sec. BPR loss is 1.23E-02. Sample per second: 76363
# SLIM_BPR_Recommender: Epoch 16 of 300. Elapsed time 11.34 sec
# Processed 69878 (100.0%) in 1.62 sec. BPR loss is 1.30E-02. Sample per second: 43224
# SLIM_BPR_Recommender: Epoch 17 of 300. Elapsed time 12.04 sec
# Processed 69878 (100.0%) in 1.24 sec. BPR loss is 1.39E-02. Sample per second: 56138
# SLIM_BPR_Recommender: Epoch 18 of 300. Elapsed time 12.66 sec
# Processed 69878 (100.0%) in 0.88 sec. BPR loss is 1.46E-02. Sample per second: 79113
# SLIM_BPR_Recommender: Epoch 19 of 300. Elapsed time 13.30 sec
# Processed 69878 (100.0%) in 1.58 sec. BPR loss is 1.56E-02. Sample per second: 44210
# SLIM_BPR_Recommender: Epoch 20 of 300. Elapsed time 14.00 sec
# ...
# Processed 69878 (100.0%) in 1.81 sec. BPR loss is 1.40E-01. Sample per second: 38542
# SLIM_BPR_Recommender: Epoch 195 of 300. Elapsed time 2.30 min
# Processed 69878 (100.0%) in 1.61 sec. BPR loss is 1.39E-01. Sample per second: 43505
# SLIM_BPR_Recommender: Epoch 196 of 300. Elapsed time 2.32 min
# Processed 69878 (100.0%) in 1.21 sec. BPR loss is 1.40E-01. Sample per second: 57674
# SLIM_BPR_Recommender: Epoch 197 of 300. Elapsed time 2.33 min
# Processed 69878 (100.0%) in 0.83 sec. BPR loss is 1.39E-01. Sample per second: 83588
# SLIM_BPR_Recommender: Epoch 198 of 300. Elapsed time 2.34 min
# Processed 69878 (100.0%) in 1.52 sec. BPR loss is 1.40E-01. Sample per second: 46055
# SLIM_BPR_Recommender: Epoch 199 of 300. Elapsed time 2.35 min
# Processed 69878 (100.0%) in 1.44 sec. BPR loss is 1.42E-01. Sample per second: 48549
# SLIM_BPR_Recommender: Epoch 200 of 300. Elapsed time 2.36 min
# Processed 69878 (100.0%) in 1.09 sec. BPR loss is 1.43E-01. Sample per second: 63836
# SLIM_BPR_Recommender: Epoch 201 of 300. Elapsed time 2.38 min
# Processed 69878 (100.0%) in 0.91 sec. BPR loss is 1.43E-01. Sample per second: 76385
# SLIM_BPR_Recommender: Epoch 202 of 300. Elapsed time 2.39 min
# Processed 69878 (100.0%) in 1.88 sec. BPR loss is 1.45E-01. Sample per second: 37173
# SLIM_BPR_Recommender: Epoch 203 of 300. Elapsed time 2.40 min
# Processed 69878 (100.0%) in 1.81 sec. BPR loss is 1.46E-01. Sample per second: 38588
# SLIM_BPR_Recommender: Epoch 204 of 300. Elapsed time 2.42 min
# Processed 69878 (100.0%) in 1.46 sec. BPR loss is 1.47E-01. Sample per second: 47920
# SLIM_BPR_Recommender: Epoch 205 of 300. Elapsed time 2.43 min
# Processed 69878 (100.0%) in 1.01 sec. BPR loss is 1.46E-01. Sample per second: 69485
# SLIM_BPR_Recommender: Epoch 206 of 300. Elapsed time 2.44 min
# Processed 69878 (100.0%) in 0.65 sec. BPR loss is 1.47E-01. Sample per second: 107015
# SLIM_BPR_Recommender: Epoch 207 of 300. Elapsed time 2.45 min
# Processed 69878 (100.0%) in 1.52 sec. BPR loss is 1.46E-01. Sample per second: 45970
# SLIM_BPR_Recommender: Epoch 208 of 300. Elapsed time 2.47 min
# Processed 69878 (100.0%) in 1.70 sec. BPR loss is 1.49E-01. Sample per second: 41166
# SLIM_BPR_Recommender: Epoch 209 of 300. Elapsed time 2.49 min
# Processed 69878 (100.0%) in 1.53 sec. BPR loss is 1.50E-01. Sample per second: 45743
# SLIM_BPR_Recommender: Epoch 210 of 300. Elapsed time 2.50 min
# Processed 69878 (100.0%) in 1.12 sec. BPR loss is 1.48E-01. Sample per second: 62279
# SLIM_BPR_Recommender: Epoch 211 of 300. Elapsed time 2.51 min
# Processed 69878 (100.0%) in 1.05 sec. BPR loss is 1.51E-01. Sample per second: 66673
# SLIM_BPR_Recommender: Epoch 212 of 300. Elapsed time 2.52 min
# Processed 69878 (100.0%) in 0.85 sec. BPR loss is 1.51E-01. Sample per second: 81896
# SLIM_BPR_Recommender: Epoch 213 of 300. Elapsed time 2.54 min
# Processed 69878 (100.0%) in 1.52 sec. BPR loss is 1.53E-01. Sample per second: 46016
# SLIM_BPR_Recommender: Epoch 214 of 300. Elapsed time 2.55 min
# Processed 69878 (100.0%) in 1.13 sec. BPR loss is 1.51E-01. Sample per second: 61570
# SLIM_BPR_Recommender: Epoch 215 of 300. Elapsed time 2.56 min
# Processed 69878 (100.0%) in 0.77 sec. BPR loss is 1.54E-01. Sample per second: 90248
# SLIM_BPR_Recommender: Epoch 216 of 300. Elapsed time 2.57 min
# Processed 69878 (100.0%) in 1.44 sec. BPR loss is 1.54E-01. Sample per second: 48540
# SLIM_BPR_Recommender: Epoch 217 of 300. Elapsed time 2.58 min
# Processed 69878 (100.0%) in 1.01 sec. BPR loss is 1.53E-01. Sample per second: 69116
# SLIM_BPR_Recommender: Epoch 218 of 300. Elapsed time 2.59 min
# Processed 69878 (100.0%) in 0.75 sec. BPR loss is 1.55E-01. Sample per second: 92952
# SLIM_BPR_Recommender: Epoch 219 of 300. Elapsed time 2.60 min
# Processed 69878 (100.0%) in 1.65 sec. BPR loss is 1.54E-01. Sample per second: 42380
# SLIM_BPR_Recommender: Epoch 220 of 300. Elapsed time 2.62 min
# Processed 69878 (100.0%) in 1.25 sec. BPR loss is 1.57E-01. Sample per second: 55848
# SLIM_BPR_Recommender: Epoch 221 of 300. Elapsed time 2.63 min
# Processed 69878 (100.0%) in 0.86 sec. BPR loss is 1.56E-01. Sample per second: 81575
# SLIM_BPR_Recommender: Epoch 222 of 300. Elapsed time 2.64 min
# Processed 69878 (100.0%) in 1.52 sec. BPR loss is 1.58E-01. Sample per second: 45884
# SLIM_BPR_Recommender: Epoch 223 of 300. Elapsed time 2.65 min
# Processed 69878 (100.0%) in 1.17 sec. BPR loss is 1.60E-01. Sample per second: 59508
# SLIM_BPR_Recommender: Epoch 224 of 300. Elapsed time 2.66 min
# Processed 69878 (100.0%) in 0.87 sec. BPR loss is 1.61E-01. Sample per second: 79956
# SLIM_BPR_Recommender: Epoch 225 of 300. Elapsed time 2.67 min
# Processed 69878 (100.0%) in 1.58 sec. BPR loss is 1.58E-01. Sample per second: 44248
# SLIM_BPR_Recommender: Epoch 226 of 300. Elapsed time 2.68 min
# Processed 69878 (100.0%) in 1.23 sec. BPR loss is 1.60E-01. Sample per second: 56785
# SLIM_BPR_Recommender: Epoch 227 of 300. Elapsed time 2.69 min
# Processed 69878 (100.0%) in 1.00 sec. BPR loss is 1.62E-01. Sample per second: 69477
# SLIM_BPR_Recommender: Epoch 228 of 300. Elapsed time 2.71 min
# Processed 69878 (100.0%) in 0.73 sec. BPR loss is 1.57E-01. Sample per second: 96113
# SLIM_BPR_Recommender: Epoch 229 of 300. Elapsed time 2.72 min
# Processed 69878 (100.0%) in 1.34 sec. BPR loss is 1.63E-01. Sample per second: 52327
# SLIM_BPR_Recommender: Epoch 230 of 300. Elapsed time 2.73 min
# Processed 69878 (100.0%) in 1.20 sec. BPR loss is 1.64E-01. Sample per second: 58255
# SLIM_BPR_Recommender: Epoch 231 of 300. Elapsed time 2.74 min
# Processed 69878 (100.0%) in 0.75 sec. BPR loss is 1.63E-01. Sample per second: 92804
# SLIM_BPR_Recommender: Epoch 232 of 300. Elapsed time 2.75 min
# Processed 69878 (100.0%) in 1.46 sec. BPR loss is 1.62E-01. Sample per second: 47886
# SLIM_BPR_Recommender: Epoch 233 of 300. Elapsed time 2.76 min
# Processed 69878 (100.0%) in 1.06 sec. BPR loss is 1.62E-01. Sample per second: 66071
# SLIM_BPR_Recommender: Epoch 234 of 300. Elapsed time 2.77 min
# Processed 69878 (100.0%) in 0.66 sec. BPR loss is 1.65E-01. Sample per second: 106192
# SLIM_BPR_Recommender: Epoch 235 of 300. Elapsed time 2.78 min
# Processed 69878 (100.0%) in 1.50 sec. BPR loss is 1.67E-01. Sample per second: 46612
# SLIM_BPR_Recommender: Epoch 236 of 300. Elapsed time 2.80 min
# Processed 69878 (100.0%) in 1.09 sec. BPR loss is 1.66E-01. Sample per second: 63958
# SLIM_BPR_Recommender: Epoch 237 of 300. Elapsed time 2.81 min
# Processed 69878 (100.0%) in 0.75 sec. BPR loss is 1.68E-01. Sample per second: 92446
# SLIM_BPR_Recommender: Epoch 238 of 300. Elapsed time 2.82 min
# Processed 69878 (100.0%) in 1.50 sec. BPR loss is 1.67E-01. Sample per second: 46613
# SLIM_BPR_Recommender: Epoch 239 of 300. Elapsed time 2.83 min
# Processed 69878 (100.0%) in 1.20 sec. BPR loss is 1.68E-01. Sample per second: 58164
# SLIM_BPR_Recommender: Epoch 240 of 300. Elapsed time 2.84 min
# Processed 69878 (100.0%) in 0.78 sec. BPR loss is 1.68E-01. Sample per second: 89268
# SLIM_BPR_Recommender: Epoch 241 of 300. Elapsed time 2.85 min
# Processed 69878 (100.0%) in 1.56 sec. BPR loss is 1.70E-01. Sample per second: 44679
# SLIM_BPR_Recommender: Epoch 242 of 300. Elapsed time 2.87 min
# Processed 69878 (100.0%) in 1.39 sec. BPR loss is 1.72E-01. Sample per second: 50267
# SLIM_BPR_Recommender: Epoch 243 of 300. Elapsed time 2.88 min
# Processed 69878 (100.0%) in 1.23 sec. BPR loss is 1.72E-01. Sample per second: 56668
# SLIM_BPR_Recommender: Epoch 244 of 300. Elapsed time 2.89 min
# Processed 69878 (100.0%) in 1.08 sec. BPR loss is 1.72E-01. Sample per second: 64567
# SLIM_BPR_Recommender: Epoch 245 of 300. Elapsed time 2.91 min
# Processed 69878 (100.0%) in 0.78 sec. BPR loss is 1.73E-01. Sample per second: 89640
# SLIM_BPR_Recommender: Epoch 246 of 300. Elapsed time 2.92 min
# Processed 69878 (100.0%) in 1.40 sec. BPR loss is 1.71E-01. Sample per second: 49952
# SLIM_BPR_Recommender: Epoch 247 of 300. Elapsed time 2.93 min
# Processed 69878 (100.0%) in 1.29 sec. BPR loss is 1.74E-01. Sample per second: 54266
# SLIM_BPR_Recommender: Epoch 248 of 300. Elapsed time 2.95 min
# Processed 69878 (100.0%) in 1.15 sec. BPR loss is 1.73E-01. Sample per second: 60909
# SLIM_BPR_Recommender: Epoch 249 of 300. Elapsed time 2.96 min
# Processed 69878 (100.0%) in 0.83 sec. BPR loss is 1.73E-01. Sample per second: 83832
# SLIM_BPR_Recommender: Epoch 250 of 300. Elapsed time 2.97 min
# Processed 69878 (100.0%) in 1.50 sec. BPR loss is 1.76E-01. Sample per second: 46527
# SLIM_BPR_Recommender: Epoch 251 of 300. Elapsed time 2.98 min
# Processed 69878 (100.0%) in 1.10 sec. BPR loss is 1.75E-01. Sample per second: 63453
# SLIM_BPR_Recommender: Epoch 252 of 300. Elapsed time 2.99 min
# Processed 69878 (100.0%) in 0.98 sec. BPR loss is 1.76E-01. Sample per second: 71134
# SLIM_BPR_Recommender: Epoch 253 of 300. Elapsed time 3.01 min
# Processed 69878 (100.0%) in 1.63 sec. BPR loss is 1.79E-01. Sample per second: 42773
# SLIM_BPR_Recommender: Epoch 254 of 300. Elapsed time 3.02 min
# Processed 69878 (100.0%) in 1.30 sec. BPR loss is 1.78E-01. Sample per second: 53629
# SLIM_BPR_Recommender: Epoch 255 of 300. Elapsed time 3.03 min
# Processed 69878 (100.0%) in 1.18 sec. BPR loss is 1.81E-01. Sample per second: 58865
# SLIM_BPR_Recommender: Epoch 256 of 300. Elapsed time 3.04 min
# Processed 69878 (100.0%) in 1.19 sec. BPR loss is 1.78E-01. Sample per second: 58816
# SLIM_BPR_Recommender: Epoch 257 of 300. Elapsed time 3.06 min
# Processed 69878 (100.0%) in 0.82 sec. BPR loss is 1.78E-01. Sample per second: 85108
# SLIM_BPR_Recommender: Epoch 258 of 300. Elapsed time 3.07 min
# Processed 69878 (100.0%) in 1.56 sec. BPR loss is 1.78E-01. Sample per second: 44872
# SLIM_BPR_Recommender: Epoch 259 of 300. Elapsed time 3.08 min
# Processed 69878 (100.0%) in 1.52 sec. BPR loss is 1.81E-01. Sample per second: 45782
# SLIM_BPR_Recommender: Epoch 260 of 300. Elapsed time 3.10 min
# Processed 69878 (100.0%) in 1.42 sec. BPR loss is 1.82E-01. Sample per second: 49216
# SLIM_BPR_Recommender: Epoch 261 of 300. Elapsed time 3.11 min
# Processed 69878 (100.0%) in 1.12 sec. BPR loss is 1.82E-01. Sample per second: 62219
# SLIM_BPR_Recommender: Epoch 262 of 300. Elapsed time 3.13 min
# Processed 69878 (100.0%) in 0.80 sec. BPR loss is 1.81E-01. Sample per second: 87629
# SLIM_BPR_Recommender: Epoch 263 of 300. Elapsed time 3.14 min
# Processed 69878 (100.0%) in 1.40 sec. BPR loss is 1.83E-01. Sample per second: 49778
# SLIM_BPR_Recommender: Epoch 264 of 300. Elapsed time 3.15 min
# Processed 69878 (100.0%) in 1.10 sec. BPR loss is 1.83E-01. Sample per second: 63463
# SLIM_BPR_Recommender: Epoch 265 of 300. Elapsed time 3.16 min
# Processed 69878 (100.0%) in 1.02 sec. BPR loss is 1.85E-01. Sample per second: 68431
# SLIM_BPR_Recommender: Epoch 266 of 300. Elapsed time 3.17 min
# Processed 69878 (100.0%) in 0.59 sec. BPR loss is 1.83E-01. Sample per second: 119130
# SLIM_BPR_Recommender: Epoch 267 of 300. Elapsed time 3.18 min
# Processed 69878 (100.0%) in 1.25 sec. BPR loss is 1.86E-01. Sample per second: 55953
# SLIM_BPR_Recommender: Epoch 268 of 300. Elapsed time 3.19 min
# Processed 69878 (100.0%) in 1.02 sec. BPR loss is 1.86E-01. Sample per second: 68324
# SLIM_BPR_Recommender: Epoch 269 of 300. Elapsed time 3.21 min
# Processed 69878 (100.0%) in 0.79 sec. BPR loss is 1.85E-01. Sample per second: 88133
# SLIM_BPR_Recommender: Epoch 270 of 300. Elapsed time 3.22 min
# Processed 69878 (100.0%) in 1.60 sec. BPR loss is 1.87E-01. Sample per second: 43727
# SLIM_BPR_Recommender: Epoch 271 of 300. Elapsed time 3.23 min
# Processed 69878 (100.0%) in 1.35 sec. BPR loss is 1.87E-01. Sample per second: 51866
# SLIM_BPR_Recommender: Epoch 272 of 300. Elapsed time 3.25 min
# Processed 69878 (100.0%) in 1.14 sec. BPR loss is 1.88E-01. Sample per second: 61486
# SLIM_BPR_Recommender: Epoch 273 of 300. Elapsed time 3.26 min
# Processed 69878 (100.0%) in 0.83 sec. BPR loss is 1.89E-01. Sample per second: 83510
# SLIM_BPR_Recommender: Epoch 274 of 300. Elapsed time 3.27 min
# Processed 69878 (100.0%) in 2.00 sec. BPR loss is 1.88E-01. Sample per second: 35016
# SLIM_BPR_Recommender: Epoch 275 of 300. Elapsed time 3.29 min
# Processed 69878 (100.0%) in 1.67 sec. BPR loss is 1.91E-01. Sample per second: 41846
# SLIM_BPR_Recommender: Epoch 276 of 300. Elapsed time 3.30 min
# Processed 69878 (100.0%) in 1.31 sec. BPR loss is 1.91E-01. Sample per second: 53292
# SLIM_BPR_Recommender: Epoch 277 of 300. Elapsed time 3.31 min
# Processed 69878 (100.0%) in 0.96 sec. BPR loss is 1.91E-01. Sample per second: 72747
# SLIM_BPR_Recommender: Epoch 278 of 300. Elapsed time 3.32 min
# Processed 69878 (100.0%) in 1.61 sec. BPR loss is 1.94E-01. Sample per second: 43218
# SLIM_BPR_Recommender: Epoch 279 of 300. Elapsed time 3.33 min
# Processed 69878 (100.0%) in 1.40 sec. BPR loss is 1.92E-01. Sample per second: 49950
# SLIM_BPR_Recommender: Epoch 280 of 300. Elapsed time 3.35 min
# Processed 69878 (100.0%) in 1.05 sec. BPR loss is 1.94E-01. Sample per second: 66342
# SLIM_BPR_Recommender: Epoch 281 of 300. Elapsed time 3.36 min
# Processed 69878 (100.0%) in 0.84 sec. BPR loss is 1.96E-01. Sample per second: 82844
# SLIM_BPR_Recommender: Epoch 282 of 300. Elapsed time 3.37 min
# Processed 69878 (100.0%) in 1.49 sec. BPR loss is 1.95E-01. Sample per second: 46994
# SLIM_BPR_Recommender: Epoch 283 of 300. Elapsed time 3.38 min
# Processed 69878 (100.0%) in 1.22 sec. BPR loss is 1.96E-01. Sample per second: 57408
# SLIM_BPR_Recommender: Epoch 284 of 300. Elapsed time 3.39 min
# Processed 69878 (100.0%) in 0.79 sec. BPR loss is 1.96E-01. Sample per second: 88831
# SLIM_BPR_Recommender: Epoch 285 of 300. Elapsed time 3.40 min
# Processed 69878 (100.0%) in 1.50 sec. BPR loss is 1.94E-01. Sample per second: 46557
# SLIM_BPR_Recommender: Epoch 286 of 300. Elapsed time 3.42 min
# Processed 69878 (100.0%) in 1.31 sec. BPR loss is 1.96E-01. Sample per second: 53420
# SLIM_BPR_Recommender: Epoch 287 of 300. Elapsed time 3.43 min
# Processed 69878 (100.0%) in 0.98 sec. BPR loss is 1.97E-01. Sample per second: 70912
# SLIM_BPR_Recommender: Epoch 288 of 300. Elapsed time 3.44 min
# Processed 69878 (100.0%) in 1.74 sec. BPR loss is 1.98E-01. Sample per second: 40261
# SLIM_BPR_Recommender: Epoch 289 of 300. Elapsed time 3.45 min
# Processed 69878 (100.0%) in 1.37 sec. BPR loss is 1.98E-01. Sample per second: 50784
# SLIM_BPR_Recommender: Epoch 290 of 300. Elapsed time 3.46 min
# Processed 69878 (100.0%) in 1.16 sec. BPR loss is 1.99E-01. Sample per second: 60075
# SLIM_BPR_Recommender: Epoch 291 of 300. Elapsed time 3.48 min
# Processed 69878 (100.0%) in 0.73 sec. BPR loss is 2.01E-01. Sample per second: 96041
# SLIM_BPR_Recommender: Epoch 292 of 300. Elapsed time 3.49 min
# Processed 69878 (100.0%) in 1.38 sec. BPR loss is 2.02E-01. Sample per second: 50639
# SLIM_BPR_Recommender: Epoch 293 of 300. Elapsed time 3.50 min
# Processed 69878 (100.0%) in 1.28 sec. BPR loss is 2.00E-01. Sample per second: 54507
# SLIM_BPR_Recommender: Epoch 294 of 300. Elapsed time 3.51 min
# Processed 69878 (100.0%) in 1.30 sec. BPR loss is 1.99E-01. Sample per second: 53506
# SLIM_BPR_Recommender: Epoch 295 of 300. Elapsed time 3.53 min
# Processed 69878 (100.0%) in 0.90 sec. BPR loss is 2.05E-01. Sample per second: 78046
# SLIM_BPR_Recommender: Epoch 296 of 300. Elapsed time 3.54 min
# Processed 69878 (100.0%) in 1.56 sec. BPR loss is 2.04E-01. Sample per second: 44832
# SLIM_BPR_Recommender: Epoch 297 of 300. Elapsed time 3.55 min
# Processed 69878 (100.0%) in 1.15 sec. BPR loss is 2.02E-01. Sample per second: 60973
# SLIM_BPR_Recommender: Epoch 298 of 300. Elapsed time 3.56 min
# Processed 69878 (100.0%) in 0.77 sec. BPR loss is 2.06E-01. Sample per second: 90645
# SLIM_BPR_Recommender: Epoch 299 of 300. Elapsed time 3.57 min
# Processed 69878 (100.0%) in 1.47 sec. BPR loss is 2.06E-01. Sample per second: 47369
# SLIM_BPR_Recommender: Epoch 300 of 300. Elapsed time 3.58 min
# SLIM_BPR_Recommender: Terminating at epoch 300. Elapsed time 3.65 min
# Deallocating Cython objects
# ItemKNNCBFRecommender: URM Detected 56 ( 0.5%) items with no interactions.
# Similarity column 10681 (100.0%), 5223.26 column/sec. Elapsed time 2.04 sec
# ItemKNN_CFCBF_HybridRecommender: URM Detected 56 ( 0.5%) items with no interactions.
# Similarity column 10681 (100.0%), 774.83 column/sec. Elapsed time 13.78 sec

# %%
cutoff = 10

for group_id in range(0, 20):
    
    start_pos = group_id*block_size
    end_pos = min((group_id+1)*block_size, len(profile_length))
    
    users_in_group = sorted_users[start_pos:end_pos]
    
    users_in_group_p_len = profile_length[users_in_group]
    
    print("Group {}, #users in group {}, average p.len {:.2f}, median {}, min {}, max {}".format(
        group_id, 
        users_in_group.shape[0],
        users_in_group_p_len.mean(),
        np.median(users_in_group_p_len),
        users_in_group_p_len.min(),
        users_in_group_p_len.max()))
    
    
    users_not_in_group_flag = np.isin(sorted_users, users_in_group, invert=True)
    users_not_in_group = sorted_users[users_not_in_group_flag]
    
    evaluator_test = EvaluatorHoldout(URM_test, cutoff_list=[cutoff], ignore_users=users_not_in_group)
    
    for label, recommender in recommender_object_dict.items():
        result_df, _ = evaluator_test.evaluateRecommender(recommender)
        if label in MAP_recommender_per_group:
            MAP_recommender_per_group[label].append(result_df.loc[cutoff]["MAP"])
        else:
            MAP_recommender_per_group[label] = [result_df.loc[cutoff]["MAP"]]
# Out:
# Group 0, #users in group 3493, average p.len 11.76, median 12.0, min 5, max 13
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3491 (100.0%) in 6.52 sec. Users per second: 535
# EvaluatorHoldout: Processed 3491 (100.0%) in 6.67 sec. Users per second: 524
# EvaluatorHoldout: Processed 3491 (100.0%) in 6.16 sec. Users per second: 566
# EvaluatorHoldout: Processed 3491 (100.0%) in 6.30 sec. Users per second: 554
# EvaluatorHoldout: Processed 3491 (100.0%) in 6.32 sec. Users per second: 553
# EvaluatorHoldout: Processed 3491 (100.0%) in 6.53 sec. Users per second: 534
# EvaluatorHoldout: Processed 3491 (100.0%) in 8.72 sec. Users per second: 400
# EvaluatorHoldout: Processed 3491 (100.0%) in 6.84 sec. Users per second: 510
# EvaluatorHoldout: Processed 3491 (100.0%) in 7.06 sec. Users per second: 494
# EvaluatorHoldout: Processed 3491 (100.0%) in 6.01 sec. Users per second: 581
# EvaluatorHoldout: Processed 3491 (100.0%) in 7.06 sec. Users per second: 494
# Group 1, #users in group 3493, average p.len 14.58, median 15.0, min 13, max 16
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3484 (100.0%) in 7.25 sec. Users per second: 481
# EvaluatorHoldout: Processed 3484 (100.0%) in 5.80 sec. Users per second: 601
# EvaluatorHoldout: Processed 3484 (100.0%) in 5.49 sec. Users per second: 635
# EvaluatorHoldout: Processed 3484 (100.0%) in 6.59 sec. Users per second: 529
# EvaluatorHoldout: Processed 3484 (100.0%) in 5.82 sec. Users per second: 599
# EvaluatorHoldout: Processed 3484 (100.0%) in 5.88 sec. Users per second: 592
# EvaluatorHoldout: Processed 3484 (100.0%) in 9.04 sec. Users per second: 385
# EvaluatorHoldout: Processed 3484 (100.0%) in 6.68 sec. Users per second: 521
# EvaluatorHoldout: Processed 3484 (100.0%) in 6.77 sec. Users per second: 515
# EvaluatorHoldout: Processed 3484 (100.0%) in 5.94 sec. Users per second: 586
# EvaluatorHoldout: Processed 3484 (100.0%) in 6.41 sec. Users per second: 544
# Group 2, #users in group 3493, average p.len 16.62, median 17.0, min 16, max 18
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3468 (100.0%) in 5.87 sec. Users per second: 591
# EvaluatorHoldout: Processed 3468 (100.0%) in 5.52 sec. Users per second: 628
# EvaluatorHoldout: Processed 3468 (100.0%) in 6.11 sec. Users per second: 568
# EvaluatorHoldout: Processed 3468 (100.0%) in 6.46 sec. Users per second: 537
# EvaluatorHoldout: Processed 3468 (100.0%) in 6.44 sec. Users per second: 538
# EvaluatorHoldout: Processed 3468 (100.0%) in 5.90 sec. Users per second: 587
# EvaluatorHoldout: Processed 3468 (100.0%) in 8.99 sec. Users per second: 386
# EvaluatorHoldout: Processed 3468 (100.0%) in 6.58 sec. Users per second: 527
# EvaluatorHoldout: Processed 3468 (100.0%) in 6.69 sec. Users per second: 519
# EvaluatorHoldout: Processed 3468 (100.0%) in 7.01 sec. Users per second: 495
# EvaluatorHoldout: Processed 3468 (100.0%) in 6.15 sec. Users per second: 564
# Group 3, #users in group 3493, average p.len 18.84, median 19.0, min 18, max 20
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3469 (100.0%) in 6.81 sec. Users per second: 510
# EvaluatorHoldout: Processed 3469 (100.0%) in 7.32 sec. Users per second: 474
# EvaluatorHoldout: Processed 3469 (100.0%) in 7.37 sec. Users per second: 471
# EvaluatorHoldout: Processed 3469 (100.0%) in 6.27 sec. Users per second: 553
# EvaluatorHoldout: Processed 3469 (100.0%) in 6.65 sec. Users per second: 521
# EvaluatorHoldout: Processed 3469 (100.0%) in 6.51 sec. Users per second: 533
# EvaluatorHoldout: Processed 3469 (100.0%) in 9.98 sec. Users per second: 348
# EvaluatorHoldout: Processed 3469 (100.0%) in 7.03 sec. Users per second: 494
# EvaluatorHoldout: Processed 3469 (100.0%) in 8.09 sec. Users per second: 429
# EvaluatorHoldout: Processed 3469 (100.0%) in 5.50 sec. Users per second: 630
# EvaluatorHoldout: Processed 3469 (100.0%) in 5.79 sec. Users per second: 600
# Group 4, #users in group 3493, average p.len 21.30, median 21.0, min 20, max 23
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3481 (100.0%) in 5.51 sec. Users per second: 631
# EvaluatorHoldout: Processed 3481 (100.0%) in 5.99 sec. Users per second: 581
# EvaluatorHoldout: Processed 3481 (100.0%) in 6.36 sec. Users per second: 547
# EvaluatorHoldout: Processed 3481 (100.0%) in 6.18 sec. Users per second: 564
# EvaluatorHoldout: Processed 3481 (100.0%) in 5.80 sec. Users per second: 600
# EvaluatorHoldout: Processed 3481 (100.0%) in 6.29 sec. Users per second: 553
# EvaluatorHoldout: Processed 3481 (100.0%) in 10.09 sec. Users per second: 345
# EvaluatorHoldout: Processed 3481 (100.0%) in 6.44 sec. Users per second: 540
# EvaluatorHoldout: Processed 3481 (100.0%) in 5.83 sec. Users per second: 597
# EvaluatorHoldout: Processed 3481 (100.0%) in 6.51 sec. Users per second: 535
# EvaluatorHoldout: Processed 3481 (100.0%) in 6.07 sec. Users per second: 573
# Group 5, #users in group 3493, average p.len 24.20, median 24.0, min 23, max 26
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3490 (100.0%) in 6.49 sec. Users per second: 538
# EvaluatorHoldout: Processed 3490 (100.0%) in 6.28 sec. Users per second: 556
# EvaluatorHoldout: Processed 3490 (100.0%) in 5.85 sec. Users per second: 597
# EvaluatorHoldout: Processed 3490 (100.0%) in 6.13 sec. Users per second: 569
# EvaluatorHoldout: Processed 3490 (100.0%) in 5.72 sec. Users per second: 610
# EvaluatorHoldout: Processed 3490 (100.0%) in 5.96 sec. Users per second: 585
# EvaluatorHoldout: Processed 3490 (100.0%) in 10.15 sec. Users per second: 344
# EvaluatorHoldout: Processed 3490 (100.0%) in 6.41 sec. Users per second: 545
# EvaluatorHoldout: Processed 3490 (100.0%) in 5.82 sec. Users per second: 600
# EvaluatorHoldout: Processed 3490 (100.0%) in 5.42 sec. Users per second: 643
# EvaluatorHoldout: Processed 3490 (100.0%) in 5.80 sec. Users per second: 602
# Group 6, #users in group 3493, average p.len 27.56, median 28.0, min 26, max 29
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3492 (100.0%) in 5.75 sec. Users per second: 608
# EvaluatorHoldout: Processed 3492 (100.0%) in 6.16 sec. Users per second: 567
# EvaluatorHoldout: Processed 3492 (100.0%) in 6.33 sec. Users per second: 551
# EvaluatorHoldout: Processed 3492 (100.0%) in 6.59 sec. Users per second: 530
# EvaluatorHoldout: Processed 3492 (100.0%) in 5.85 sec. Users per second: 597
# EvaluatorHoldout: Processed 3492 (100.0%) in 6.30 sec. Users per second: 554
# EvaluatorHoldout: Processed 3492 (100.0%) in 9.14 sec. Users per second: 382
# EvaluatorHoldout: Processed 3492 (100.0%) in 5.89 sec. Users per second: 592
# EvaluatorHoldout: Processed 3492 (100.0%) in 5.41 sec. Users per second: 645
# EvaluatorHoldout: Processed 3492 (100.0%) in 5.96 sec. Users per second: 586
# EvaluatorHoldout: Processed 3492 (100.0%) in 5.34 sec. Users per second: 654
# Group 7, #users in group 3493, average p.len 31.48, median 31.0, min 29, max 34
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3492 (100.0%) in 5.80 sec. Users per second: 603
# EvaluatorHoldout: Processed 3492 (100.0%) in 5.85 sec. Users per second: 597
# EvaluatorHoldout: Processed 3492 (100.0%) in 5.67 sec. Users per second: 616
# EvaluatorHoldout: Processed 3492 (100.0%) in 5.56 sec. Users per second: 628
# EvaluatorHoldout: Processed 3492 (100.0%) in 7.05 sec. Users per second: 495
# EvaluatorHoldout: Processed 3492 (100.0%) in 5.79 sec. Users per second: 603
# EvaluatorHoldout: Processed 3492 (100.0%) in 9.34 sec. Users per second: 374
# EvaluatorHoldout: Processed 3492 (100.0%) in 5.31 sec. Users per second: 658
# EvaluatorHoldout: Processed 3492 (100.0%) in 4.98 sec. Users per second: 701
# EvaluatorHoldout: Processed 3492 (100.0%) in 7.18 sec. Users per second: 487
# EvaluatorHoldout: Processed 3492 (100.0%) in 7.18 sec. Users per second: 486
# Group 8, #users in group 3493, average p.len 35.97, median 36.0, min 34, max 38
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.80 sec. Users per second: 448
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.13 sec. Users per second: 569
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.45 sec. Users per second: 469
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.26 sec. Users per second: 481
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.51 sec. Users per second: 465
# EvaluatorHoldout: Processed 3493 (100.0%) in 5.57 sec. Users per second: 628
# EvaluatorHoldout: Processed 3493 (100.0%) in 10.12 sec. Users per second: 345
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.98 sec. Users per second: 500
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.59 sec. Users per second: 530
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.07 sec. Users per second: 494
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.67 sec. Users per second: 456
# Group 9, #users in group 3493, average p.len 41.34, median 41.0, min 38, max 44
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3492 (100.0%) in 6.01 sec. Users per second: 581
# EvaluatorHoldout: Processed 3492 (100.0%) in 7.56 sec. Users per second: 462
# EvaluatorHoldout: Processed 3492 (100.0%) in 6.12 sec. Users per second: 571
# EvaluatorHoldout: Processed 3492 (100.0%) in 6.64 sec. Users per second: 526
# EvaluatorHoldout: Processed 3492 (100.0%) in 7.41 sec. Users per second: 472
# EvaluatorHoldout: Processed 3492 (100.0%) in 6.43 sec. Users per second: 543
# EvaluatorHoldout: Processed 3492 (100.0%) in 10.24 sec. Users per second: 341
# EvaluatorHoldout: Processed 3492 (100.0%) in 7.14 sec. Users per second: 489
# EvaluatorHoldout: Processed 3492 (100.0%) in 6.32 sec. Users per second: 553
# EvaluatorHoldout: Processed 3492 (100.0%) in 6.57 sec. Users per second: 531
# EvaluatorHoldout: Processed 3492 (100.0%) in 6.81 sec. Users per second: 513
# Group 10, #users in group 3493, average p.len 47.76, median 48.0, min 44, max 51
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.12 sec. Users per second: 570
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.56 sec. Users per second: 532
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.48 sec. Users per second: 467
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.10 sec. Users per second: 492
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.12 sec. Users per second: 571
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.59 sec. Users per second: 460
# EvaluatorHoldout: Processed 3493 (100.0%) in 10.76 sec. Users per second: 325
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.86 sec. Users per second: 509
# EvaluatorHoldout: Processed 3493 (100.0%) in 5.49 sec. Users per second: 637
# EvaluatorHoldout: Processed 3493 (100.0%) in 5.46 sec. Users per second: 640
# EvaluatorHoldout: Processed 3493 (100.0%) in 5.84 sec. Users per second: 598
# Group 11, #users in group 3493, average p.len 55.59, median 55.0, min 51, max 60
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3493 (100.0%) in 5.26 sec. Users per second: 664
# EvaluatorHoldout: Processed 3493 (100.0%) in 5.80 sec. Users per second: 602
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.48 sec. Users per second: 467
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.75 sec. Users per second: 517
# EvaluatorHoldout: Processed 3493 (100.0%) in 8.21 sec. Users per second: 425
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.84 sec. Users per second: 511
# EvaluatorHoldout: Processed 3493 (100.0%) in 10.51 sec. Users per second: 332
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.67 sec. Users per second: 524
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.57 sec. Users per second: 532
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.98 sec. Users per second: 500
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.55 sec. Users per second: 533
# Group 12, #users in group 3493, average p.len 64.91, median 65.0, min 60, max 70
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.90 sec. Users per second: 506
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.79 sec. Users per second: 515
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.93 sec. Users per second: 504
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.58 sec. Users per second: 531
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.68 sec. Users per second: 523
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.39 sec. Users per second: 547
# EvaluatorHoldout: Processed 3493 (100.0%) in 10.36 sec. Users per second: 337
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.16 sec. Users per second: 488
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.29 sec. Users per second: 479
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.43 sec. Users per second: 543
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.75 sec. Users per second: 451
# Group 13, #users in group 3493, average p.len 75.76, median 76.0, min 70, max 83
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.89 sec. Users per second: 507
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.20 sec. Users per second: 485
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.17 sec. Users per second: 487
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.62 sec. Users per second: 528
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.31 sec. Users per second: 554
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.10 sec. Users per second: 573
# EvaluatorHoldout: Processed 3493 (100.0%) in 10.25 sec. Users per second: 341
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.74 sec. Users per second: 518
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.13 sec. Users per second: 490
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.09 sec. Users per second: 573
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.78 sec. Users per second: 515
# Group 14, #users in group 3493, average p.len 90.87, median 91.0, min 83, max 100
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.65 sec. Users per second: 525
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.91 sec. Users per second: 505
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.14 sec. Users per second: 489
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.18 sec. Users per second: 486
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.72 sec. Users per second: 520
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.81 sec. Users per second: 513
# EvaluatorHoldout: Processed 3493 (100.0%) in 10.35 sec. Users per second: 337
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.06 sec. Users per second: 495
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.61 sec. Users per second: 528
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.23 sec. Users per second: 483
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.71 sec. Users per second: 453
# Group 15, #users in group 3493, average p.len 111.47, median 111.0, min 100, max 124
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.39 sec. Users per second: 547
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.38 sec. Users per second: 547
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.09 sec. Users per second: 493
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.10 sec. Users per second: 572
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.88 sec. Users per second: 508
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.41 sec. Users per second: 545
# EvaluatorHoldout: Processed 3493 (100.0%) in 10.52 sec. Users per second: 332
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.58 sec. Users per second: 531
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.16 sec. Users per second: 488
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.64 sec. Users per second: 526
# EvaluatorHoldout: Processed 3493 (100.0%) in 8.54 sec. Users per second: 409
# Group 16, #users in group 3493, average p.len 140.42, median 140.0, min 124, max 159
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.50 sec. Users per second: 537
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.51 sec. Users per second: 465
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.29 sec. Users per second: 479
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.08 sec. Users per second: 493
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.80 sec. Users per second: 514
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.16 sec. Users per second: 567
# EvaluatorHoldout: Processed 3493 (100.0%) in 10.78 sec. Users per second: 324
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.20 sec. Users per second: 563
# EvaluatorHoldout: Processed 3493 (100.0%) in 8.62 sec. Users per second: 405
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.94 sec. Users per second: 503
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.00 sec. Users per second: 499
# Group 17, #users in group 3493, average p.len 184.11, median 183.0, min 159, max 215
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.61 sec. Users per second: 528
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.02 sec. Users per second: 498
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.84 sec. Users per second: 511
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.02 sec. Users per second: 497
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.65 sec. Users per second: 457
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.84 sec. Users per second: 511
# EvaluatorHoldout: Processed 3493 (100.0%) in 10.36 sec. Users per second: 337
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.17 sec. Users per second: 487
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.77 sec. Users per second: 449
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.47 sec. Users per second: 468
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.47 sec. Users per second: 468
# Group 18, #users in group 3493, average p.len 262.66, median 258.0, min 215, max 328
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.66 sec. Users per second: 525
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.73 sec. Users per second: 452
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.82 sec. Users per second: 447
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.12 sec. Users per second: 571
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.82 sec. Users per second: 447
# EvaluatorHoldout: Processed 3493 (100.0%) in 5.92 sec. Users per second: 590
# EvaluatorHoldout: Processed 3493 (100.0%) in 10.71 sec. Users per second: 326
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.09 sec. Users per second: 493
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.59 sec. Users per second: 460
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.41 sec. Users per second: 545
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.32 sec. Users per second: 553
# Group 19, #users in group 3493, average p.len 541.78, median 463.0, min 328, max 1810
# EvaluatorHoldout: Ignoring 69800 ( 0.1%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 66385 Users
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.62 sec. Users per second: 528
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.23 sec. Users per second: 483
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.65 sec. Users per second: 457
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.52 sec. Users per second: 536
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.67 sec. Users per second: 455
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.67 sec. Users per second: 455
# EvaluatorHoldout: Processed 3493 (100.0%) in 11.01 sec. Users per second: 317
# EvaluatorHoldout: Processed 3493 (100.0%) in 6.99 sec. Users per second: 500
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.48 sec. Users per second: 467
# EvaluatorHoldout: Processed 3493 (100.0%) in 8.00 sec. Users per second: 437
# EvaluatorHoldout: Processed 3493 (100.0%) in 7.48 sec. Users per second: 467

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  

_ = plt.figure(figsize=(16, 9))
for label, recommender in recommender_object_dict.items():
    results = MAP_recommender_per_group[label]
    plt.scatter(x=np.arange(0,len(results)), y=results, label=label)
plt.ylabel('MAP')
plt.xlabel('User Group')
plt.legend()
plt.show()

# %% [markdown]
# ### The recommendation quality of the three algorithms changes depending on the user profile length
#
# ## Tip:
# ### If an algorithm works best on average, it does not imply it will work best for ALL user types
