# %%
import pandas as pd
import numpy as np
import scipy.sparse as sps

from scipy.sparse import *

# %%
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

# %%
urm_path = './content/data_train.csv'
urm_all_df = pd.read_csv(filepath_or_buffer=urm_path,
                                sep=",",
                                header=0,
                                dtype={0:int, 1:int, 2:float},
                                engine='python')

urm_all_df.columns = ["UserID", "ItemID", "Interaction"]

# %%
userID_unique = urm_all_df["UserID"].unique()
itemID_unique = urm_all_df["ItemID"].unique()

n_users = len(userID_unique)
n_items = len(itemID_unique)
n_interactions = len(urm_all_df)

# %%
urm_all = sps.coo_matrix((urm_all_df["Interaction"].values,
                          (urm_all_df["UserID"].values, urm_all_df["ItemID"].values)))

urm_all
# Out:
# <13025x22348 sparse matrix of type '<class 'numpy.float64'>'
# 	with 478730 stored elements in COOrdinate format>

# %%
URM_all = urm_all

# %% [markdown]
# ### Step 1: Split the data and create the evaluator objects

# %%
from Evaluation.Evaluator import EvaluatorHoldout

URM_train_validation, URM_test = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.8)
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_train_validation, train_percentage = 0.8)

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])
evaluator_test = EvaluatorHoldout(URM_test, cutoff_list=[10])
# Out:
# Warning: 590 (4.53 %) of 13025 users have no train items
# Warning: 2595 (19.92 %) of 13025 users have no sampled items
# Warning: 821 (6.30 %) of 13025 users have no train items
# Warning: 2965 (22.76 %) of 13025 users have no sampled items
# EvaluatorHoldout: Ignoring 2965 (22.8%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 2595 (19.9%) Users that have less than 1 test interactions

# %% [markdown]
# ### Step 2: Define hyperparameter set for the desired model, in this case rp3beta

# %%
from skopt.space import Real, Integer, Categorical

hyperparameters_range_dictionary = {
    "topK": Integer(1, 70),
    "shrink": Real(0, 25)
}

# %% [markdown]
# ### Step 3: Create SearchBayesianSkopt object, providing the desired recommender class and evaluator objects

# %%
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

recommender_class = ItemKNNCFRecommender

hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                         evaluator_validation=evaluator_validation,
                                         evaluator_test=evaluator_test)

# %% [markdown]
# ### Step 4: Provide the data needed to create an instance of the model, one trained only on URM_train, the other on URM_train_validation

# %%
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
  
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {},
    EARLYSTOPPING_KEYWORD_ARGS = {},
)

# %%
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train_validation],     # For a CBF model simply put [URM_train_validation, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {},
    EARLYSTOPPING_KEYWORD_ARGS = {},
)

# %% [markdown]
# ### Step 5: Create a result folder and select the number of cases (50 with 30% random is a good number)

# %%
import os

output_folder_path = "result_experiments/itemBasedCF"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 10  # using 10 as an example
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %% [markdown]
# ### Step 5: Run!

# %%
hyperparameterSearch.search(recommender_input_args,
                       recommender_input_args_last_test = recommender_input_args_last_test,
                       hyperparameter_search_space = hyperparameters_range_dictionary,
                       n_cases = n_cases,
                       n_random_starts = n_random_starts,
                       save_model = "last",
                       output_folder_path = output_folder_path, # Where to save the results
                       output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                       metric_to_optimize = metric_to_optimize,
                       cutoff_to_optimize = cutoff_to_optimize,
                      )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 29, 'shrink': 12.705693799599741}
# ItemKNNCFRecommender: URM Detected 821 ( 6.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 481 ( 2.2%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 1448.44 column/sec. Elapsed time 15.43 sec
# EvaluatorHoldout: Processed 10060 (100.0%) in 9.99 sec. Users per second: 1007
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 29, 'shrink': 12.705693799599741} - results: PRECISION: 0.0612028, PRECISION_RECALL_MIN_DEN: 0.1229484, RECALL: 0.1102508, MAP: 0.0279981, MAP_MIN_DEN: 0.0561952, MRR: 0.1846377, NDCG: 0.1039772, F1: 0.0787112, HIT_RATE: 0.4021869, ARHR_ALL_HITS: 0.2261403, NOVELTY: 0.0051989, AVERAGE_POPULARITY: 0.2023570, DIVERSITY_MEAN_INTER_LIST: 0.9767622, DIVERSITY_HERFINDAHL: 0.9976665, COVERAGE_ITEM: 0.3963218, COVERAGE_ITEM_HIT: 0.0717738, ITEMS_IN_GT: 0.7408717, COVERAGE_USER: 0.7723608, COVERAGE_USER_HIT: 0.3106334, USERS_IN_GT: 0.7723608, DIVERSITY_GINI: 0.0747111, SHANNON_ENTROPY: 10.4451116, RATIO_DIVERSITY_HERFINDAHL: 0.9980270, RATIO_DIVERSITY_GINI: 0.2179625, RATIO_SHANNON_ENTROPY: 0.8051735, RATIO_AVERAGE_POPULARITY: 1.7099597, RATIO_NOVELTY: 0.3807417,
#
# EvaluatorHoldout: Processed 10430 (100.0%) in 10.20 sec. Users per second: 1023
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'topK': 29, 'shrink': 12.705693799599741} - results:
# CUTOFF: 10 - PRECISION: 0.0721189, PRECISION_RECALL_MIN_DEN: 0.1258888, RECALL: 0.1064479, MAP: 0.0342977, MAP_MIN_DEN: 0.0600907, MRR: 0.2115728, NDCG: 0.1131825, F1: 0.0859836, HIT_RATE: 0.4418025, ARHR_ALL_HITS: 0.2672200, NOVELTY: 0.0052177, AVERAGE_POPULARITY: 0.2005300, DIVERSITY_MEAN_INTER_LIST: 0.9770245, DIVERSITY_HERFINDAHL: 0.9976931, COVERAGE_ITEM: 0.4120279, COVERAGE_ITEM_HIT: 0.0771881, ITEMS_IN_GT: 0.8004743, COVERAGE_USER: 0.8007678, COVERAGE_USER_HIT: 0.3537812, USERS_IN_GT: 0.8007678, DIVERSITY_GINI: 0.0774747, SHANNON_ENTROPY: 10.4769799, RATIO_DIVERSITY_HERFINDAHL: 0.9980535, RATIO_DIVERSITY_GINI: 0.2260252, RATIO_SHANNON_ENTROPY: 0.8076301, RATIO_AVERAGE_POPULARITY: 1.6945211, RATIO_NOVELTY: 0.3821180,
#
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 36.1124
# Function value obtained: -0.0280
# Current minimum: -0.0280
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 40, 'shrink': 24.672687709798147}
# ItemKNNCFRecommender: URM Detected 821 ( 6.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 481 ( 2.2%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 1428.35 column/sec. Elapsed time 15.65 sec
# EvaluatorHoldout: Processed 10060 (100.0%) in 10.63 sec. Users per second: 946
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'topK': 40, 'shrink': 24.672687709798147} - results: PRECISION: 0.0610636, PRECISION_RECALL_MIN_DEN: 0.1242719, RECALL: 0.1117306, MAP: 0.0279052, MAP_MIN_DEN: 0.0562924, MRR: 0.1850101, NDCG: 0.1043487, F1: 0.0789688, HIT_RATE: 0.4038767, ARHR_ALL_HITS: 0.2260669, NOVELTY: 0.0050282, AVERAGE_POPULARITY: 0.2312950, DIVERSITY_MEAN_INTER_LIST: 0.9702960, DIVERSITY_HERFINDAHL: 0.9970200, COVERAGE_ITEM: 0.3190890, COVERAGE_ITEM_HIT: 0.0619295, ITEMS_IN_GT: 0.7408717, COVERAGE_USER: 0.7723608, COVERAGE_USER_HIT: 0.3119386, USERS_IN_GT: 0.7723608, DIVERSITY_GINI: 0.0527710, SHANNON_ENTROPY: 9.9952764, RATIO_DIVERSITY_HERFINDAHL: 0.9973802, RATIO_DIVERSITY_GINI: 0.1539545, RATIO_SHANNON_ENTROPY: 0.7704974, RATIO_AVERAGE_POPULARITY: 1.9544923, RATIO_NOVELTY: 0.3682428,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 26.6840
# Function value obtained: -0.0279
# Current minimum: -0.0280
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 6, 'shrink': 5.022933762692762}
# ItemKNNCFRecommender: URM Detected 821 ( 6.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 481 ( 2.2%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 1577.00 column/sec. Elapsed time 14.17 sec
# EvaluatorHoldout: Processed 10060 (100.0%) in 9.13 sec. Users per second: 1102
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'topK': 6, 'shrink': 5.022933762692762} - results: PRECISION: 0.0590755, PRECISION_RECALL_MIN_DEN: 0.1147760, RECALL: 0.1024531, MAP: 0.0270728, MAP_MIN_DEN: 0.0539192, MRR: 0.1811059, NDCG: 0.0996709, F1: 0.0749399, HIT_RATE: 0.3896620, ARHR_ALL_HITS: 0.2200653, NOVELTY: 0.0055897, AVERAGE_POPULARITY: 0.1433504, DIVERSITY_MEAN_INTER_LIST: 0.9839864, DIVERSITY_HERFINDAHL: 0.9983889, COVERAGE_ITEM: 0.5081887, COVERAGE_ITEM_HIT: 0.0817523, ITEMS_IN_GT: 0.7408717, COVERAGE_USER: 0.7723608, COVERAGE_USER_HIT: 0.3009597, USERS_IN_GT: 0.7723608, DIVERSITY_GINI: 0.1185956, SHANNON_ENTROPY: 11.0867658, RATIO_DIVERSITY_HERFINDAHL: 0.9987496, RATIO_DIVERSITY_GINI: 0.3459913, RATIO_SHANNON_ENTROPY: 0.8546361, RATIO_AVERAGE_POPULARITY: 1.2113418, RATIO_NOVELTY: 0.4093641,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 23.9436
# Function value obtained: -0.0271
# Current minimum: -0.0280
# Iteration No: 4 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 70, 'shrink': 0.6252090791532136}
# ItemKNNCFRecommender: URM Detected 821 ( 6.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 481 ( 2.2%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 1250.68 column/sec. Elapsed time 17.87 sec
# EvaluatorHoldout: Processed 10060 (100.0%) in 10.32 sec. Users per second: 975
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 70, 'shrink': 0.6252090791532136} - results: PRECISION: 0.0538171, PRECISION_RECALL_MIN_DEN: 0.1068397, RECALL: 0.0957821, MAP: 0.0244125, MAP_MIN_DEN: 0.0485268, MRR: 0.1641164, NDCG: 0.0907783, F1: 0.0689137, HIT_RATE: 0.3624254, ARHR_ALL_HITS: 0.1992159, NOVELTY: 0.0059043, AVERAGE_POPULARITY: 0.1767042, DIVERSITY_MEAN_INTER_LIST: 0.9790480, DIVERSITY_HERFINDAHL: 0.9978951, COVERAGE_ITEM: 0.5720870, COVERAGE_ITEM_HIT: 0.0706551, ITEMS_IN_GT: 0.7408717, COVERAGE_USER: 0.7723608, COVERAGE_USER_HIT: 0.2799232, USERS_IN_GT: 0.7723608, DIVERSITY_GINI: 0.1590628, SHANNON_ENTROPY: 11.3514527, RATIO_DIVERSITY_HERFINDAHL: 0.9982556, RATIO_DIVERSITY_GINI: 0.4640507, RATIO_SHANNON_ENTROPY: 0.8750398, RATIO_AVERAGE_POPULARITY: 1.4931884, RATIO_NOVELTY: 0.4324084,
#
# Iteration No: 4 ended. Search finished for the next optimal point.
# Time taken: 28.8690
# Function value obtained: -0.0244
# Current minimum: -0.0280
# Iteration No: 5 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 19, 'shrink': 24.820626719228585}
# ItemKNNCFRecommender: URM Detected 821 ( 6.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 481 ( 2.2%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 1389.53 column/sec. Elapsed time 16.08 sec
# EvaluatorHoldout: Processed 10060 (100.0%) in 10.11 sec. Users per second: 995
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 19, 'shrink': 24.820626719228585} - results: PRECISION: 0.0603380, PRECISION_RECALL_MIN_DEN: 0.1218807, RECALL: 0.1094211, MAP: 0.0277898, MAP_MIN_DEN: 0.0564153, MRR: 0.1862973, NDCG: 0.1037985, F1: 0.0777837, HIT_RATE: 0.4009940, ARHR_ALL_HITS: 0.2262112, NOVELTY: 0.0051073, AVERAGE_POPULARITY: 0.2062285, DIVERSITY_MEAN_INTER_LIST: 0.9760588, DIVERSITY_HERFINDAHL: 0.9975962, COVERAGE_ITEM: 0.3277698, COVERAGE_ITEM_HIT: 0.0649723, ITEMS_IN_GT: 0.7408717, COVERAGE_USER: 0.7723608, COVERAGE_USER_HIT: 0.3097121, USERS_IN_GT: 0.7723608, DIVERSITY_GINI: 0.0571219, SHANNON_ENTROPY: 10.1903327, RATIO_DIVERSITY_HERFINDAHL: 0.9979566, RATIO_DIVERSITY_GINI: 0.1666479, RATIO_SHANNON_ENTROPY: 0.7855335, RATIO_AVERAGE_POPULARITY: 1.7426744, RATIO_NOVELTY: 0.3740332,
#
# Iteration No: 5 ended. Search finished for the next optimal point.
# Time taken: 26.7687
# Function value obtained: -0.0278
# Current minimum: -0.0280
# Iteration No: 6 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 48, 'shrink': 19.522945574853292}
# ItemKNNCFRecommender: URM Detected 821 ( 6.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 481 ( 2.2%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 1197.12 column/sec. Elapsed time 18.67 sec
# EvaluatorHoldout: Processed 10060 (100.0%) in 11.16 sec. Users per second: 901
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': 48, 'shrink': 19.522945574853292} - results: PRECISION: 0.0613718, PRECISION_RECALL_MIN_DEN: 0.1244267, RECALL: 0.1118469, MAP: 0.0278596, MAP_MIN_DEN: 0.0561610, MRR: 0.1849544, NDCG: 0.1042986, F1: 0.0792552, HIT_RATE: 0.4057654, ARHR_ALL_HITS: 0.2257752, NOVELTY: 0.0050509, AVERAGE_POPULARITY: 0.2318428, DIVERSITY_MEAN_INTER_LIST: 0.9697891, DIVERSITY_HERFINDAHL: 0.9969693, COVERAGE_ITEM: 0.3365849, COVERAGE_ITEM_HIT: 0.0644353, ITEMS_IN_GT: 0.7408717, COVERAGE_USER: 0.7723608, COVERAGE_USER_HIT: 0.3133973, USERS_IN_GT: 0.7723608, DIVERSITY_GINI: 0.0569990, SHANNON_ENTROPY: 10.0522134, RATIO_DIVERSITY_HERFINDAHL: 0.9973295, RATIO_DIVERSITY_GINI: 0.1662892, RATIO_SHANNON_ENTROPY: 0.7748865, RATIO_AVERAGE_POPULARITY: 1.9591207, RATIO_NOVELTY: 0.3699065,
#
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 30.4946
# Function value obtained: -0.0279
# Current minimum: -0.0280
# Iteration No: 7 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 70, 'shrink': 10.781659807124623}
# ItemKNNCFRecommender: URM Detected 821 ( 6.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 481 ( 2.2%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 1222.07 column/sec. Elapsed time 18.29 sec
# EvaluatorHoldout: Processed 10060 (100.0%) in 11.28 sec. Users per second: 892
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'topK': 70, 'shrink': 10.781659807124623} - results: PRECISION: 0.0605169, PRECISION_RECALL_MIN_DEN: 0.1221723, RECALL: 0.1099166, MAP: 0.0275224, MAP_MIN_DEN: 0.0559679, MRR: 0.1849355, NDCG: 0.1035229, F1: 0.0780576, HIT_RATE: 0.4046720, ARHR_ALL_HITS: 0.2243902, NOVELTY: 0.0051239, AVERAGE_POPULARITY: 0.2345095, DIVERSITY_MEAN_INTER_LIST: 0.9677336, DIVERSITY_HERFINDAHL: 0.9967637, COVERAGE_ITEM: 0.4019152, COVERAGE_ITEM_HIT: 0.0684178, ITEMS_IN_GT: 0.7408717, COVERAGE_USER: 0.7723608, COVERAGE_USER_HIT: 0.3125528, USERS_IN_GT: 0.7723608, DIVERSITY_GINI: 0.0724541, SHANNON_ENTROPY: 10.2190425, RATIO_DIVERSITY_HERFINDAHL: 0.9971239, RATIO_DIVERSITY_GINI: 0.2113781, RATIO_SHANNON_ENTROPY: 0.7877467, RATIO_AVERAGE_POPULARITY: 1.9816552, RATIO_NOVELTY: 0.3752530,
#
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 30.3358
# Function value obtained: -0.0275
# Current minimum: -0.0280
# Iteration No: 8 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1, 'shrink': 0.09468739347140712}
# ItemKNNCFRecommender: URM Detected 821 ( 6.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 481 ( 2.2%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 1738.25 column/sec. Elapsed time 12.86 sec
# EvaluatorHoldout: Processed 10060 (100.0%) in 8.43 sec. Users per second: 1193
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'topK': 1, 'shrink': 0.09468739347140712} - results: PRECISION: 0.0413022, PRECISION_RECALL_MIN_DEN: 0.0741055, RECALL: 0.0655818, MAP: 0.0180214, MAP_MIN_DEN: 0.0362039, MRR: 0.1319821, NDCG: 0.0683317, F1: 0.0506843, HIT_RATE: 0.3005964, ARHR_ALL_HITS: 0.1536671, NOVELTY: 0.0061272, AVERAGE_POPULARITY: 0.0953771, DIVERSITY_MEAN_INTER_LIST: 0.8812154, DIVERSITY_HERFINDAHL: 0.9881128, COVERAGE_ITEM: 0.4429479, COVERAGE_ITEM_HIT: 0.0741453, ITEMS_IN_GT: 0.7408717, COVERAGE_USER: 0.7723608, COVERAGE_USER_HIT: 0.2321689, USERS_IN_GT: 0.7723608, DIVERSITY_GINI: 0.0761269, SHANNON_ENTROPY: 9.4423307, RATIO_DIVERSITY_HERFINDAHL: 0.9884698, RATIO_DIVERSITY_GINI: 0.2220932, RATIO_SHANNON_ENTROPY: 0.7278730, RATIO_AVERAGE_POPULARITY: 0.8059569, RATIO_NOVELTY: 0.4487324,
#
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 22.0044
# Function value obtained: -0.0180
# Current minimum: -0.0280
# Iteration No: 9 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 70, 'shrink': 15.913090538660091}
# ItemKNNCFRecommender: URM Detected 821 ( 6.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 481 ( 2.2%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 1442.74 column/sec. Elapsed time 15.49 sec
# EvaluatorHoldout: Processed 10060 (100.0%) in 10.12 sec. Users per second: 994
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'topK': 70, 'shrink': 15.913090538660091} - results: PRECISION: 0.0605666, PRECISION_RECALL_MIN_DEN: 0.1227372, RECALL: 0.1104370, MAP: 0.0276168, MAP_MIN_DEN: 0.0561261, MRR: 0.1857892, NDCG: 0.1038605, F1: 0.0782299, HIT_RATE: 0.4053678, ARHR_ALL_HITS: 0.2253022, NOVELTY: 0.0050421, AVERAGE_POPULARITY: 0.2430737, DIVERSITY_MEAN_INTER_LIST: 0.9657458, DIVERSITY_HERFINDAHL: 0.9965650, COVERAGE_ITEM: 0.3511276, COVERAGE_ITEM_HIT: 0.0642116, ITEMS_IN_GT: 0.7408717, COVERAGE_USER: 0.7723608, COVERAGE_USER_HIT: 0.3130902, USERS_IN_GT: 0.7723608, DIVERSITY_GINI: 0.0593134, SHANNON_ENTROPY: 10.0101072, RATIO_DIVERSITY_HERFINDAHL: 0.9969250, RATIO_DIVERSITY_GINI: 0.1730411, RATIO_SHANNON_ENTROPY: 0.7716407, RATIO_AVERAGE_POPULARITY: 2.0540248, RATIO_NOVELTY: 0.3692611,
#
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 26.3204
# Function value obtained: -0.0276
# Current minimum: -0.0280
# Iteration No: 10 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 1, 'shrink': 8.81746263213482}
# ItemKNNCFRecommender: URM Detected 821 ( 6.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 481 ( 2.2%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 2045.44 column/sec. Elapsed time 10.93 sec
# EvaluatorHoldout: Processed 10060 (100.0%) in 8.09 sec. Users per second: 1243
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': 1, 'shrink': 8.81746263213482} - results: PRECISION: 0.0466998, PRECISION_RECALL_MIN_DEN: 0.0838378, RECALL: 0.0732529, MAP: 0.0222110, MAP_MIN_DEN: 0.0426128, MRR: 0.1600607, NDCG: 0.0795302, F1: 0.0570374, HIT_RATE: 0.3308151, ARHR_ALL_HITS: 0.1876893, NOVELTY: 0.0058738, AVERAGE_POPULARITY: 0.1091935, DIVERSITY_MEAN_INTER_LIST: 0.9610630, DIVERSITY_HERFINDAHL: 0.9960967, COVERAGE_ITEM: 0.4712726, COVERAGE_ITEM_HIT: 0.0721317, ITEMS_IN_GT: 0.7408717, COVERAGE_USER: 0.7723608, COVERAGE_USER_HIT: 0.2555086, USERS_IN_GT: 0.7723608, DIVERSITY_GINI: 0.1054586, SHANNON_ENTROPY: 10.6586798, RATIO_DIVERSITY_HERFINDAHL: 0.9964566, RATIO_DIVERSITY_GINI: 0.3076656, RATIO_SHANNON_ENTROPY: 0.8216366, RATIO_AVERAGE_POPULARITY: 0.9227086, RATIO_NOVELTY: 0.4301693,
#
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 19.6408
# Function value obtained: -0.0222
# Current minimum: -0.0280
# SearchBayesianSkopt: Search complete. Best config is 0: {'topK': 29, 'shrink': 12.705693799599741}
#
# ItemKNNCFRecommender: URM Detected 590 ( 4.5%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 241 ( 1.1%) items with no interactions.
# SearchBayesianSkopt: Evaluation with constructor data for final test. Using best config: {'topK': 29, 'shrink': 12.705693799599741}
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 1486.81 column/sec. Elapsed time 15.03 sec
# EvaluatorHoldout: Processed 10430 (100.0%) in 9.61 sec. Users per second: 1085
# SearchBayesianSkopt: Best config evaluated with evaluator_test with constructor data for final test. Config: {'topK': 29, 'shrink': 12.705693799599741} - results:
# CUTOFF: 10 - PRECISION: 0.0847651, PRECISION_RECALL_MIN_DEN: 0.1475682, RECALL: 0.1238142, MAP: 0.0430547, MAP_MIN_DEN: 0.0730558, MRR: 0.2451540, NDCG: 0.1336159, F1: 0.1006344, HIT_RATE: 0.4796740, ARHR_ALL_HITS: 0.3207164, NOVELTY: 0.0051717, AVERAGE_POPULARITY: 0.2005066, DIVERSITY_MEAN_INTER_LIST: 0.9773128, DIVERSITY_HERFINDAHL: 0.9977219, COVERAGE_ITEM: 0.3781099, COVERAGE_ITEM_HIT: 0.0907911, ITEMS_IN_GT: 0.8004743, COVERAGE_USER: 0.8007678, COVERAGE_USER_HIT: 0.3841075, USERS_IN_GT: 0.8007678, DIVERSITY_GINI: 0.0695861, SHANNON_ENTROPY: 10.4138546, RATIO_DIVERSITY_HERFINDAHL: 0.9980826, RATIO_DIVERSITY_GINI: 0.2005428, RATIO_SHANNON_ENTROPY: 0.8021496, RATIO_AVERAGE_POPULARITY: 1.6786459, RATIO_NOVELTY: 0.3027694,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/itemBasedCFItemKNNCFRecommender
#
# ItemKNNCFRecommender: Saving model in file 'result_experiments/itemBasedCFItemKNNCFRecommender_best_model_last'
# ItemKNNCFRecommender: Saving complete

# %% [markdown]
# ### Check the best model

# %%
from Recommenders.DataIO import DataIO

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_metadata.zip")

search_metadata.keys()
# Out:
# dict_keys(['algorithm_name_recommender', 'algorithm_name_search', 'cutoff_to_optimize', 'exception_list', 'hyperparameters_best', 'hyperparameters_best_index', 'hyperparameters_df', 'metric_to_optimize', 'result_on_earlystopping_df', 'result_on_last', 'result_on_test_best', 'result_on_test_df', 'result_on_validation_best', 'result_on_validation_df', 'time_df', 'time_on_last_df', 'time_on_test_avg', 'time_on_test_total', 'time_on_train_avg', 'time_on_train_total', 'time_on_validation_avg', 'time_on_validation_total'])

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#   topK     shrink
# 0   29  12.705694
# 1   40  24.672688
# 2    6   5.022934
# 3   70   0.625209
# 4   19  24.820627
# 5   48  19.522946
# 6   70   10.78166
# 7    1   0.094687
# 8   70  15.913091
# 9    1   8.817463

# %%
result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#          PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#   cutoff
# 0 10      0.061203                 0.122948  0.110251  0.027998    0.056195
# 1 10      0.061064                 0.124272  0.111731  0.027905    0.056292
# 2 10      0.059076                 0.114776  0.102453  0.027073    0.053919
# 3 10      0.053817                  0.10684  0.095782  0.024412    0.048527
# 4 10      0.060338                 0.121881  0.109421   0.02779    0.056415
# 5 10      0.061372                 0.124427  0.111847   0.02786    0.056161
# 6 10      0.060517                 0.122172  0.109917  0.027522    0.055968
# 7 10      0.041302                 0.074105  0.065582  0.018021    0.036204
# 8 10      0.060567                 0.122737  0.110437  0.027617    0.056126
# 9 10        0.0467                 0.083838  0.073253  0.022211    0.042613
#
#                MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#   cutoff                                                        ...
# 0 10      0.184638  0.103977  0.078711  0.402187       0.22614  ...
# 1 10       0.18501  0.104349  0.078969  0.403877      0.226067  ...
# 2 10      0.181106  0.099671   0.07494  0.389662      0.220065  ...
# 3 10      0.164116  0.090778  0.068914  0.362425      0.199216  ...
# 4 10      0.186297  0.103799  0.077784  0.400994      0.226211  ...
# 5 10      0.184954  0.104299  0.079255  0.405765      0.225775  ...
# 6 10      0.184935  0.103523  0.078058  0.404672       0.22439  ...
# 7 10      0.131982  0.068332  0.050684  0.300596      0.153667  ...
# 8 10      0.185789   0.10386   0.07823  0.405368      0.225302  ...
# 9 10      0.160061   0.07953  0.057037  0.330815      0.187689  ...
#
#          COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
#   cutoff
# 0 10          0.772361          0.310633    0.772361       0.074711
# 1 10          0.772361          0.311939    0.772361       0.052771
# 2 10          0.772361           0.30096    0.772361       0.118596
# 3 10          0.772361          0.279923    0.772361       0.159063
# 4 10          0.772361          0.309712    0.772361       0.057122
# 5 10          0.772361          0.313397    0.772361       0.056999
# 6 10          0.772361          0.312553    0.772361       0.072454
# 7 10          0.772361          0.232169    0.772361       0.076127
# 8 10          0.772361           0.31309    0.772361       0.059313
# 9 10          0.772361          0.255509    0.772361       0.105459
#
#          SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
#   cutoff
# 0 10           10.445112                   0.998027             0.217963
# 1 10            9.995276                    0.99738             0.153955
# 2 10           11.086766                    0.99875             0.345991
# 3 10           11.351453                   0.998256             0.464051
# 4 10           10.190333                   0.997957             0.166648
# 5 10           10.052213                   0.997329             0.166289
# 6 10           10.219043                   0.997124             0.211378
# 7 10            9.442331                    0.98847             0.222093
# 8 10           10.010107                   0.996925             0.173041
# 9 10            10.65868                   0.996457             0.307666
#
#          RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
#   cutoff
# 0 10                  0.805173                  1.70996      0.380742
# 1 10                  0.770497                 1.954492      0.368243
# 2 10                  0.854636                 1.211342      0.409364
# 3 10                   0.87504                 1.493188      0.432408
# 4 10                  0.785534                 1.742674      0.374033
# 5 10                  0.774886                 1.959121      0.369907
# 6 10                  0.787747                 1.981655      0.375253
# 7 10                  0.727873                 0.805957      0.448732
# 8 10                  0.771641                 2.054025      0.369261
# 9 10                  0.821637                 0.922709      0.430169
#
# [10 rows x 27 columns]

# %%
result_best_on_test = search_metadata["result_on_last"]
result_best_on_test
# Out:
#        PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.084765                 0.147568  0.123814  0.043055    0.073056
#
#              MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                        ...
# 10      0.245154  0.133616  0.100634  0.479674      0.320716  ...
#
#        COVERAGE_USER COVERAGE_USER_HIT USERS_IN_GT DIVERSITY_GINI  \
# cutoff
# 10          0.800768          0.384107    0.800768       0.069586
#
#        SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL RATIO_DIVERSITY_GINI  \
# cutoff
# 10           10.413855                   0.998083             0.200543
#
#        RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY RATIO_NOVELTY
# cutoff
# 10                   0.80215                 1.678646      0.302769
#
# [1 rows x 27 columns]

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'topK': 29, 'shrink': 12.705693799599741}

# %%
time_df = search_metadata["time_df"]
time_df
# Out:
#        train validation       test
# 0  15.466024   9.999763  10.222719
# 1  15.691022  10.648482        NaN
# 2  14.197238   9.139916        NaN
# 3  17.944624   10.32967        NaN
# 4  16.119162   10.12214        NaN
# 5   18.72022  11.179429        NaN
# 6  18.365956  11.296324        NaN
# 7  12.877626   8.450758        NaN
# 8  15.559988  10.132651        NaN
# 9  10.944769   8.106719        NaN

# %%
exception_list = search_metadata["exception_list"]
exception_list
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# # Some useful evaluation

# %%
def precision(recommended_items, relevant_items):
    
    is_relevant = np.in1d(recommended_items, relevant_items, assume_unique=True)
    
    precision_score = np.sum(is_relevant, dtype=np.float32) / len(is_relevant)
    
    return precision_score

def recall(recommended_items, relevant_items):
    
    is_relevant = np.in1d(recommended_items, relevant_items, assume_unique=True)
    
    recall_score = np.sum(is_relevant, dtype=np.float32) / relevant_items.shape[0]
    
    return recall_score

def AP(recommended_items, relevant_items):

    is_relevant = np.in1d(recommended_items, relevant_items, assume_unique=True)
    
    # Cumulative sum: precision at 1, at 2, at 3 ...
    p_at_k = is_relevant * np.cumsum(is_relevant, dtype=np.float32) / (1 + np.arange(is_relevant.shape[0]))
    
    ap_score = np.sum(p_at_k) / np.min([relevant_items.shape[0], is_relevant.shape[0]])

    return ap_score

# We pass as paramether the recommender class and the URM test

def evaluate_algorithm(URM_test, recommender_object, at=5):
    
    cumulative_precision = 0.0
    cumulative_recall = 0.0
    cumulative_AP = 0.0
    
    num_eval = 0


    for user_id in range(URM_test.shape[0]):

        relevant_items = URM_test.indices[URM_test.indptr[user_id]:URM_test.indptr[user_id+1]]
        
        if len(relevant_items)>0:
            
            recommended_items = recommender_object.recommend(user_id, cutoff = 10)
            num_eval+=1

            cumulative_precision += precision(recommended_items, relevant_items)
            cumulative_recall += recall(recommended_items, relevant_items)
            cumulative_AP += AP(recommended_items, relevant_items)
            
    cumulative_precision /= num_eval
    cumulative_recall /= num_eval
    MAP = cumulative_AP / num_eval
    
    print("Recommender results are: Precision = {:.4f}, Recall = {:.4f}, MAP = {:.4f}".format(
        cumulative_precision, cumulative_recall, MAP))

# %% [markdown]
# First our found model with Bayesian Search:

# %%
recommender = ItemKNNCFRecommender(URM_train)
recommender.fit(topK=29,shrink=12.705693799599741)

evaluate_algorithm(URM_test,recommender)
# Out:
# ItemKNNCFRecommender: URM Detected 821 ( 6.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 481 ( 2.2%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 1228.31 column/sec. Elapsed time 18.19 sec
# Recommender results are: Precision = 0.0721, Recall = 0.1064, MAP = 0.0601

# %%
recommender = ItemKNNCFRecommender(URM_train)
recommender.fit(topK=14,shrink=7)

evaluate_algorithm(URM_test,recommender)
# Out:
# ItemKNNCFRecommender: URM Detected 827 ( 6.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 473 ( 2.1%) items with no interactions.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 22348 (100.0%), 1304.59 column/sec. Elapsed time 17.13 sec
# Recommender results are: Precision = 0.0746, Recall = 0.1097, MAP = 0.0609
